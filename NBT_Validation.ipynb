# %%
#Data saved in csv/excel
import glob, os
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

data_dir="R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc"
os.chdir(data_dir)

# %% [markdown]
# # Get the data

# %%
# get all assessment files
afiles = glob.glob('R:\\MSS\\Research\\Projects\\Baby_Toolbox\\Validation_Data\\misc\\*Assessment Data.csv')

doc =[]
for file in afiles:
    if '2021-11-1' in file and 'Narrow Structure' not in file:
        data = pd.read_csv(file)
        print(file)
        doc.append(data)

# get all reg files 
rdoc =[]
rfiles = glob.glob('R:\\MSS\\Research\\Projects\\Baby_Toolbox\\Validation_Data\\misc\\*Registration Data.csv')
for file in rfiles:
    if '2021-11-1' in file and 'Narrow Structure' not in file:
        data = pd.read_csv(file)
        print(file)
        rdoc.append(data)

adf = pd.concat(doc)
rdf = pd.concat(rdoc)
# Out:
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-10 15.22.31 Assessment Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-16 14.04.33 Assessment Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-16 10.57.43 Assessment Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-18 16.58.51 Assessment Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-16 17.15.37 Assessment Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-17 11.41.39 Assessment Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-18 17.10.29 Assessment Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-14 17.33.44 Assessment Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-14 10.36.57 Assessment Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-11 09.46.56 Assessment Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-13 10.49.41 Assessment Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-16 14.18.51 Assessment Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-12 10.25.39 Assessment Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-17 13.06.07 Assessment Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-13 14.36.11 Assessment Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-13 10.15.55 Assessment Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-12 14.42.57 Assessment Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-13 15.17.57 Assessment Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-17 11.47.06 Assessment Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-17 13.01.41 Assessment Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-14 14.18.15 Assessment Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-12 14.18.46 Assessment Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-10 15.16.40 Assessment Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-12 13.38.57 Assessment Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-11 09.40.09 Assessment Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-15 14.19.25 Assessment Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-16 14.08.02 Assessment Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-18 10.48.06 Assessment Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-16 17.09.38 Assessment Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-10 17.50.35 Assessment Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-10 17.49.48 Assessment Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-11 14.31.03 Assessment Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-17 13.01.48 Assessment Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-14 15.18.20 Assessment Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-16 13.59.31 Assessment Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-13 11.49.16 Assessment Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-12 15.57.15 Assessment Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-13 18.03.08 Assessment Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-15 09.53.28 Assessment Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-14 11.55.14 Assessment Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-17 17.52.21 Assessment Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-17 17.50.57 Assessment Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-13 14.11.18 Assessment Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-12 10.48.54 Assessment Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-14 14.35.41 Assessment Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-16 18.14.30 Assessment Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-11 10.13.29 Assessment Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-13 10.15.34 Assessment Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-10 14.53.04 Assessment Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-16 14.46.00 Assessment Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-13 14.17.36 Assessment Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-17 12.17.54 Assessment Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-14 17.45.29 Assessment Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-14 10.47.31 Assessment Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-16 17.40.42 Assessment Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-11 11.44.51 Assessment Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-19 11.33.13 Assessment Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-11 14.20.17 Assessment Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-15 15.45.39 Assessment Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-13 14.35.51 Assessment Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-16 14.07.38 Assessment Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-19 11.03.56 Assessment Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-16 13.59.49 Assessment Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-10 14.52.12 Assessment Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-17 09.51.48 Assessment Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-11 12.13.03 Assessment Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-12 15.14.12 Assessment Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-15 13.38.05 Assessment Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-12 09.53.57 Assessment Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-14 17.33.03 Assessment Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-14 11.55.21 Assessment Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-12 16.17.00 Assessment Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-16 11.02.16 Assessment Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-19 18.04.29 Assessment Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-16 14.46.02 Assessment Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-17 16.48.12 Assessment Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-11 17.05.13 Assessment Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-18 11.41.44 Assessment Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-14 13.43.30 Assessment Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-15 13.39.56 Assessment Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-16 10.58.09 Assessment Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-14 17.40.02 Assessment Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-12 10.52.41 Assessment Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-14 14.18.32 Assessment Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-11 14.26.33 Assessment Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-11 12.28.25 Assessment Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-19 18.04.02 Assessment Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-11 14.08.42 Assessment Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-18 10.00.06 Assessment Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-17 14.08.22 Assessment Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-12 14.42.13 Assessment Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-11 12.15.15 Assessment Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-18 10.15.31 Assessment Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-12 14.18.10 Assessment Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-13 11.55.37 Assessment Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-14 15.34.07 Assessment Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-14 10.16.56 Assessment Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-17 16.47.42 Assessment Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-17 10.19.45 Assessment Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-17 17.41.42 Assessment Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-15 10.01.47 Assessment Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-16 14.18.30 Assessment Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-12 15.13.36 Assessment Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-14 10.47.07 Assessment Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-15 15.45.23 Assessment Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-13 15.16.18 Assessment Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-19 11.04.23 Assessment Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-12 13.38.34 Assessment Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-15 17.44.24 Assessment Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-18 11.46.57 Assessment Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-18 16.58.33 Assessment Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-14 14.18.32 Registration Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-19 11.33.13 Registration Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-17 16.47.42 Registration Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-14 17.40.02 Registration Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-10 14.52.12 Registration Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-12 14.42.13 Registration Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-14 10.47.31 Registration Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-11 14.20.17 Registration Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-13 14.17.36 Registration Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-12 15.57.15 Registration Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-16 14.08.02 Registration Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-12 14.18.10 Registration Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-19 18.04.29 Registration Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-10 17.50.35 Registration Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-16 17.40.42 Registration Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-17 17.50.57 Registration Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-12 10.25.39 Registration Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-16 17.15.37 Registration Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-15 14.19.25 Registration Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-14 14.35.41 Registration Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-10 17.49.48 Registration Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-17 13.01.41 Registration Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-18 11.41.44 Registration Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-10 14.53.04 Registration Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-12 10.48.54 Registration Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-16 13.59.49 Registration Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-14 14.18.15 Registration Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-15 15.45.23 Registration Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-13 11.49.16 Registration Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-11 09.40.09 Registration Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-18 17.10.29 Registration Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-13 15.17.57 Registration Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-19 11.03.56 Registration Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-17 17.52.21 Registration Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-17 13.06.07 Registration Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-11 14.08.42 Registration Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-14 15.18.20 Registration Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-17 12.17.54 Registration Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-16 17.09.38 Registration Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-14 11.55.14 Registration Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-11 09.46.56 Registration Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-15 09.53.28 Registration Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-12 14.42.57 Registration Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-14 10.47.07 Registration Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-14 17.45.29 Registration Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-15 15.45.39 Registration Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-11 10.13.29 Registration Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-12 13.38.57 Registration Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-16 10.57.43 Registration Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-13 10.15.34 Registration Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-16 14.46.02 Registration Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-14 13.43.30 Registration Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-17 16.48.12 Registration Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-10 15.16.40 Registration Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-16 14.18.51 Registration Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-11 14.31.03 Registration Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-11 17.05.13 Registration Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-12 09.53.57 Registration Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-11 11.44.51 Registration Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-13 15.16.18 Registration Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-13 18.03.08 Registration Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-16 10.58.09 Registration Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-14 15.34.07 Registration Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-13 10.49.41 Registration Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-13 10.15.55 Registration Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-16 13.59.31 Registration Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-18 10.00.06 Registration Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-12 13.38.34 Registration Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-16 14.07.38 Registration Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-10 15.22.31 Registration Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-17 14.08.22 Registration Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-17 10.19.45 Registration Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-15 13.39.56 Registration Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-12 15.13.36 Registration Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-18 10.15.31 Registration Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-15 10.01.47 Registration Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-18 10.48.06 Registration Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-11 12.13.03 Registration Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-13 14.11.18 Registration Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-14 10.16.56 Registration Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-17 11.41.39 Registration Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-14 17.33.44 Registration Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-17 13.01.48 Registration Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-12 15.14.12 Registration Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-16 11.02.16 Registration Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-16 14.18.30 Registration Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-15 17.44.24 Registration Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-12 16.17.00 Registration Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-19 11.04.23 Registration Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-13 11.55.37 Registration Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-14 17.33.03 Registration Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-13 14.35.51 Registration Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-11 12.15.15 Registration Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-12 10.52.41 Registration Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-16 18.14.30 Registration Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-11 14.26.33 Registration Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-17 09.51.48 Registration Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-17 17.41.42 Registration Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-15 13.38.05 Registration Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-18 16.58.33 Registration Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-14 11.55.21 Registration Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-16 14.04.33 Registration Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-12 14.18.46 Registration Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-18 11.46.57 Registration Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-14 10.36.57 Registration Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-13 14.36.11 Registration Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-19 18.04.02 Registration Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-18 16.58.51 Registration Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-11 12.28.25 Registration Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-16 14.46.00 Registration Data.csv
# R:\MSS\Research\Projects\Baby_Toolbox\Validation_Data\misc\2021-11-17 11.47.06 Registration Data.csv

# %%
rdf.shape
# Out:
# (140, 14)

# %%
rdf=rdf.reset_index()

# %%
rdf=rdf.drop_duplicates()

# %%
rdf =rdf.drop(columns=['index'])

# %%
rdf.at[97,'PIN']='mn018p'

# %%
subset = rdf.groupby("PIN").filter(lambda x: len(x) > 1)
subset
# Out:
#         PIN                              DeviceID  \
# 10   WI008P  10B77F95-1027-483B-9126-666988F60440
# 13   Mn012c  53A3EB94-4ACF-41E6-A744-01E877B21025
# 16   WI013C  F6DB0E9E-9CDF-4144-917F-A34E300BDDF9
# 17   WI013C  F6DB0E9E-9CDF-4144-917F-A34E300BDDF9
# 27   Mn015p  70508CF6-2178-46E9-9F9A-2A7E7FB8A07F
# 28   WI020C  E2909A06-4CF6-4F3A-A839-A30AE05F2B5B
# 46   WI031C  10B77F95-1027-483B-9126-666988F60440
# 47   WI031C  10B77F95-1027-483B-9126-666988F60440
# 51   WI023P  10B77F95-1027-483B-9126-666988F60440
# 52   WI023P  10B77F95-1027-483B-9126-666988F60440
# 54   Mn012c  13781795-A391-4367-BA54-1152B446E0D8
# 57   WI003C  E2909A06-4CF6-4F3A-A839-A30AE05F2B5B
# 58   WI003C  E2909A06-4CF6-4F3A-A839-A30AE05F2B5B
# 61   WI008P  059282F7-D6F7-4A39-8DF8-429BD89241D1
# 64   WI026P  10B77F95-1027-483B-9126-666988F60440
# 68   WI020C  10B77F95-1027-483B-9126-666988F60440
# 72   WI005C  E2909A06-4CF6-4F3A-A839-A30AE05F2B5B
# 84   WI033C  E2909A06-4CF6-4F3A-A839-A30AE05F2B5B
# 85   WI033C  E2909A06-4CF6-4F3A-A839-A30AE05F2B5B
# 90   Mn015p  70508CF6-2178-46E9-9F9A-2A7E7FB8A07F
# 102  Mn015p  AA12C32E-3CCC-4FA8-9CDA-D4FCFDD70BB6
# 108  WI026P  10B77F95-1027-483B-9126-666988F60440
# 132  WI005C  E2909A06-4CF6-4F3A-A839-A30AE05F2B5B
# 138  WI031C  E2909A06-4CF6-4F3A-A839-A30AE05F2B5B
# 139  WI031C  E2909A06-4CF6-4F3A-A839-A30AE05F2B5B
#
#                                              Name    Age  Education  \
# 10                                           Liam   23:8        NaN
# 13                                         Mn012p    2:3        NaN
# 16                                         Elodie    2:0        1.0
# 17                                         Elodie    NaN        1.0
# 27                                         Mn015c   37:1       18.0
# 28                                           Remy    3:5        NaN
# 46                                           Kyla    NaN        NaN
# 47                                           Kyla   38:1        NaN
# 51                                       Marshall    NaN        NaN
# 52                                       Marshall   34:6        NaN
# 54                                         Mn012p  32:10        NaN
# 57                                           Isla    NaN        NaN
# 58                                           Isla    1:0        NaN
# 61                                        Greyson    2:3        1.0
# 64                                          Wyatt   34:3        NaN
# 68                                           Remy  27:10        NaN
# 72                                           Myla    NaN       16.0
# 84                                         Blaire    NaN        NaN
# 85                                         Blaire    1:7        NaN
# 90                                         Mn015c    NaN       18.0
# 102  Mn018c the real parent id for this is mn018p   36:7       18.0
# 108                                         Wyatt   34:3        NaN
# 132                                          Myla    2:4       16.0
# 138                                          Kyla    NaN        NaN
# 139                                          Kyla    1:1        NaN
#
#      MothersEducation  FathersEducation  GuardiansEducation  \
# 10               25.0               NaN                 NaN
# 13               22.0               NaN                 NaN
# 16               21.0               NaN                 NaN
# 17               21.0               NaN                 NaN
# 27               16.0               NaN                 NaN
# 28               16.0               NaN                 NaN
# 46               20.0               NaN                 NaN
# 47               20.0               NaN                 NaN
# 51               21.0               NaN                 NaN
# 52               21.0               NaN                 NaN
# 54                NaN               NaN                 NaN
# 57                NaN               NaN                 NaN
# 58                NaN               NaN                 NaN
# 61               21.0               NaN                 NaN
# 64               18.0               NaN                 NaN
# 68               16.0               NaN                 NaN
# 72                NaN               NaN                 NaN
# 84               20.0               NaN                 NaN
# 85               20.0               NaN                 NaN
# 90               16.0               NaN                 NaN
# 102              21.0               NaN                 NaN
# 108              18.0               NaN                 NaN
# 132               NaN               NaN                 NaN
# 138              20.0               NaN                 NaN
# 139              20.0               NaN                 NaN
#
#      StartingLevelOverride  Gender  Handedness  Race  Ethnicity  \
# 10                     NaN     2.0         1.0     1        1.0
# 13                     NaN     1.0         NaN     1        1.0
# 16                     NaN     2.0         1.0     1        1.0
# 17                     NaN     2.0         1.0     1        1.0
# 27                     NaN     1.0         1.0     1        1.0
# 28                     NaN     1.0         NaN     1        1.0
# 46                     NaN     2.0         1.0     1        1.0
# 47                     NaN     2.0         1.0     1        1.0
# 51                     NaN     2.0         1.0     1        1.0
# 52                     NaN     2.0         1.0     1        1.0
# 54                     NaN     2.0         NaN     1        1.0
# 57                     NaN     2.0         NaN     1        1.0
# 58                     NaN     2.0         NaN     1        1.0
# 61                     NaN     1.0         1.0     1        1.0
# 64                     NaN     2.0         2.0     1        1.0
# 68                     NaN     1.0         2.0     1        1.0
# 72                     NaN     2.0         1.0     0        NaN
# 84                     NaN     2.0         NaN     1        1.0
# 85                     NaN     2.0         NaN     1        1.0
# 90                     NaN     1.0         1.0     1        1.0
# 102                    NaN     2.0         1.0    32        1.0
# 108                    NaN     2.0         2.0     1        1.0
# 132                    NaN     2.0         1.0     0        NaN
# 138                    NaN     2.0         NaN     1        1.0
# 139                    NaN     2.0         NaN     1        1.0
#
#     Assessment Name
# 10     Assessment 1
# 13     Assessment 1
# 16     Assessment 1
# 17     Assessment 2
# 27     Assessment 1
# 28     Assessment 1
# 46     Assessment 1
# 47     Assessment 2
# 51     Assessment 1
# 52     Assessment 2
# 54     Assessment 1
# 57     Assessment 1
# 58     Assessment 2
# 61     Assessment 2
# 64     Assessment 2
# 68     Assessment 1
# 72     Assessment 1
# 84     Assessment 1
# 85     Assessment 2
# 90     Assessment 2
# 102    Assessment 2
# 108    Assessment 1
# 132    Assessment 2
# 138    Assessment 1
# 139    Assessment 2

# %%
dropindex = [14,41,42,43,46,49,52,56,61,63,65,75,79,84,85,91,92,103,124,125,126,127,128,129,130,131]

# %%
for pin in subset.PIN.unique():
    display(subset[subset['PIN']==pin])
# Out:
#        PIN                              DeviceID     Name   Age  Education  \
# 10  WI008P  10B77F95-1027-483B-9126-666988F60440     Liam  23:8        NaN
# 61  WI008P  059282F7-D6F7-4A39-8DF8-429BD89241D1  Greyson   2:3        1.0
#
#     MothersEducation  FathersEducation  GuardiansEducation  \
# 10              25.0               NaN                 NaN
# 61              21.0               NaN                 NaN
#
#     StartingLevelOverride  Gender  Handedness  Race  Ethnicity Assessment Name
# 10                    NaN     2.0         1.0     1        1.0    Assessment 1
# 61                    NaN     1.0         1.0     1        1.0    Assessment 2
#        PIN                              DeviceID    Name    Age  Education  \
# 13  Mn012c  53A3EB94-4ACF-41E6-A744-01E877B21025  Mn012p    2:3        NaN
# 54  Mn012c  13781795-A391-4367-BA54-1152B446E0D8  Mn012p  32:10        NaN
#
#     MothersEducation  FathersEducation  GuardiansEducation  \
# 13              22.0               NaN                 NaN
# 54               NaN               NaN                 NaN
#
#     StartingLevelOverride  Gender  Handedness  Race  Ethnicity Assessment Name
# 13                    NaN     1.0         NaN     1        1.0    Assessment 1
# 54                    NaN     2.0         NaN     1        1.0    Assessment 1
#        PIN                              DeviceID    Name  Age  Education  \
# 16  WI013C  F6DB0E9E-9CDF-4144-917F-A34E300BDDF9  Elodie  2:0        1.0
# 17  WI013C  F6DB0E9E-9CDF-4144-917F-A34E300BDDF9  Elodie  NaN        1.0
#
#     MothersEducation  FathersEducation  GuardiansEducation  \
# 16              21.0               NaN                 NaN
# 17              21.0               NaN                 NaN
#
#     StartingLevelOverride  Gender  Handedness  Race  Ethnicity Assessment Name
# 16                    NaN     2.0         1.0     1        1.0    Assessment 1
# 17                    NaN     2.0         1.0     1        1.0    Assessment 2
#         PIN                              DeviceID  \
# 27   Mn015p  70508CF6-2178-46E9-9F9A-2A7E7FB8A07F
# 90   Mn015p  70508CF6-2178-46E9-9F9A-2A7E7FB8A07F
# 102  Mn015p  AA12C32E-3CCC-4FA8-9CDA-D4FCFDD70BB6
#
#                                              Name   Age  Education  \
# 27                                         Mn015c  37:1       18.0
# 90                                         Mn015c   NaN       18.0
# 102  Mn018c the real parent id for this is mn018p  36:7       18.0
#
#      MothersEducation  FathersEducation  GuardiansEducation  \
# 27               16.0               NaN                 NaN
# 90               16.0               NaN                 NaN
# 102              21.0               NaN                 NaN
#
#      StartingLevelOverride  Gender  Handedness  Race  Ethnicity  \
# 27                     NaN     1.0         1.0     1        1.0
# 90                     NaN     1.0         1.0     1        1.0
# 102                    NaN     2.0         1.0    32        1.0
#
#     Assessment Name
# 27     Assessment 1
# 90     Assessment 2
# 102    Assessment 2
#        PIN                              DeviceID  Name    Age  Education  \
# 28  WI020C  E2909A06-4CF6-4F3A-A839-A30AE05F2B5B  Remy    3:5        NaN
# 68  WI020C  10B77F95-1027-483B-9126-666988F60440  Remy  27:10        NaN
#
#     MothersEducation  FathersEducation  GuardiansEducation  \
# 28              16.0               NaN                 NaN
# 68              16.0               NaN                 NaN
#
#     StartingLevelOverride  Gender  Handedness  Race  Ethnicity Assessment Name
# 28                    NaN     1.0         NaN     1        1.0    Assessment 1
# 68                    NaN     1.0         2.0     1        1.0    Assessment 1
#         PIN                              DeviceID  Name   Age  Education  \
# 46   WI031C  10B77F95-1027-483B-9126-666988F60440  Kyla   NaN        NaN
# 47   WI031C  10B77F95-1027-483B-9126-666988F60440  Kyla  38:1        NaN
# 138  WI031C  E2909A06-4CF6-4F3A-A839-A30AE05F2B5B  Kyla   NaN        NaN
# 139  WI031C  E2909A06-4CF6-4F3A-A839-A30AE05F2B5B  Kyla   1:1        NaN
#
#      MothersEducation  FathersEducation  GuardiansEducation  \
# 46               20.0               NaN                 NaN
# 47               20.0               NaN                 NaN
# 138              20.0               NaN                 NaN
# 139              20.0               NaN                 NaN
#
#      StartingLevelOverride  Gender  Handedness  Race  Ethnicity  \
# 46                     NaN     2.0         1.0     1        1.0
# 47                     NaN     2.0         1.0     1        1.0
# 138                    NaN     2.0         NaN     1        1.0
# 139                    NaN     2.0         NaN     1        1.0
#
#     Assessment Name
# 46     Assessment 1
# 47     Assessment 2
# 138    Assessment 1
# 139    Assessment 2
#        PIN                              DeviceID      Name   Age  Education  \
# 51  WI023P  10B77F95-1027-483B-9126-666988F60440  Marshall   NaN        NaN
# 52  WI023P  10B77F95-1027-483B-9126-666988F60440  Marshall  34:6        NaN
#
#     MothersEducation  FathersEducation  GuardiansEducation  \
# 51              21.0               NaN                 NaN
# 52              21.0               NaN                 NaN
#
#     StartingLevelOverride  Gender  Handedness  Race  Ethnicity Assessment Name
# 51                    NaN     2.0         1.0     1        1.0    Assessment 1
# 52                    NaN     2.0         1.0     1        1.0    Assessment 2
#        PIN                              DeviceID  Name  Age  Education  \
# 57  WI003C  E2909A06-4CF6-4F3A-A839-A30AE05F2B5B  Isla  NaN        NaN
# 58  WI003C  E2909A06-4CF6-4F3A-A839-A30AE05F2B5B  Isla  1:0        NaN
#
#     MothersEducation  FathersEducation  GuardiansEducation  \
# 57               NaN               NaN                 NaN
# 58               NaN               NaN                 NaN
#
#     StartingLevelOverride  Gender  Handedness  Race  Ethnicity Assessment Name
# 57                    NaN     2.0         NaN     1        1.0    Assessment 1
# 58                    NaN     2.0         NaN     1        1.0    Assessment 2
#         PIN                              DeviceID   Name   Age  Education  \
# 64   WI026P  10B77F95-1027-483B-9126-666988F60440  Wyatt  34:3        NaN
# 108  WI026P  10B77F95-1027-483B-9126-666988F60440  Wyatt  34:3        NaN
#
#      MothersEducation  FathersEducation  GuardiansEducation  \
# 64               18.0               NaN                 NaN
# 108              18.0               NaN                 NaN
#
#      StartingLevelOverride  Gender  Handedness  Race  Ethnicity  \
# 64                     NaN     2.0         2.0     1        1.0
# 108                    NaN     2.0         2.0     1        1.0
#
#     Assessment Name
# 64     Assessment 2
# 108    Assessment 1
#         PIN                              DeviceID  Name  Age  Education  \
# 72   WI005C  E2909A06-4CF6-4F3A-A839-A30AE05F2B5B  Myla  NaN       16.0
# 132  WI005C  E2909A06-4CF6-4F3A-A839-A30AE05F2B5B  Myla  2:4       16.0
#
#      MothersEducation  FathersEducation  GuardiansEducation  \
# 72                NaN               NaN                 NaN
# 132               NaN               NaN                 NaN
#
#      StartingLevelOverride  Gender  Handedness  Race  Ethnicity  \
# 72                     NaN     2.0         1.0     0        NaN
# 132                    NaN     2.0         1.0     0        NaN
#
#     Assessment Name
# 72     Assessment 1
# 132    Assessment 2
#        PIN                              DeviceID    Name  Age  Education  \
# 84  WI033C  E2909A06-4CF6-4F3A-A839-A30AE05F2B5B  Blaire  NaN        NaN
# 85  WI033C  E2909A06-4CF6-4F3A-A839-A30AE05F2B5B  Blaire  1:7        NaN
#
#     MothersEducation  FathersEducation  GuardiansEducation  \
# 84              20.0               NaN                 NaN
# 85              20.0               NaN                 NaN
#
#     StartingLevelOverride  Gender  Handedness  Race  Ethnicity Assessment Name
# 84                    NaN     2.0         NaN     1        1.0    Assessment 1
# 85                    NaN     2.0         NaN     1        1.0    Assessment 2

# %%
subset.PIN.nunique()
# Out:
# 11

# %%
len(subset.drop(dropindex))

# %%
rdf= rdf.drop(dropindex)

# %%
#sanity check
rdf.groupby("PIN").filter(lambda x: len(x) > 1)

# %%
#Set two decimal points for display
pd.options.display.float_format = "{:.2f}".format

# %%
rdf[['Year','Month']] = rdf.Age.str.split(":",expand=True)

# %%
rdf['Month'] =pd.to_numeric(rdf['Month'])
rdf['Year'] =pd.to_numeric(rdf['Year'])

# %%
#recode the age into months format
rdf['Age_month'] = rdf['Year']*12 + rdf['Month']

# %%
rdf= rdf.drop_duplicates()

# %%
adf= adf.drop_duplicates()

# %%
adf.shape

# %%
#Recode age group
rdf['Age_group'] = pd.cut(rdf['Age_month'] , [0,1,2,3,4,5,6,8,10,12,15,18,21,24,27,30,35,43])

# %%
# Concatenate registration and assessment data files in the /misc folder
df = pd.merge(adf, rdf[['PIN','Assessment Name', 'Age_month','Age_group']], on=['PIN','Assessment Name'], how ='left')

# %%
df.shape

# %%
df.PIN.nunique()

# %%
df.head()
# Out:
#           PIN                              DeviceID Assessment Name  InstOrdr  \
# 0  Appletonc1  E2909A06-4CF6-4F3A-A839-A30AE05F2B5B    Assessment 1         1
# 1  Appletonc1  E2909A06-4CF6-4F3A-A839-A30AE05F2B5B    Assessment 1         1
# 2  Appletonc1  E2909A06-4CF6-4F3A-A839-A30AE05F2B5B    Assessment 1         1
# 3  Appletonc1  E2909A06-4CF6-4F3A-A839-A30AE05F2B5B    Assessment 1         2
# 4  Appletonc1  E2909A06-4CF6-4F3A-A839-A30AE05F2B5B    Assessment 1         2
#
#    InstSctn  ItmOrdr                        Inst Locale  \
# 0         1        1            Mullen Receptive  en-US
# 1         1        2            Mullen Receptive  en-US
# 2         1       15            Mullen Receptive  en-US
# 3         1        1  Mullen Expressive Prompted  en-US
# 4         1        2  Mullen Expressive Prompted  en-US
#
#                      ItemID Response  ... Position  ResponseTime  \
# 0          Mullen_Rec_Title        1  ...        1           NaN
# 1   Mullen_Rec_Instructions        1  ...        2           NaN
# 2                      RL22        2  ...        3           NaN
# 3         Mullen_ExpP_Title        1  ...        1           NaN
# 4  Mullen_ExpP_Instructions        1  ...        2           NaN
#
#            DateCreated          InstStarted            InstEnded  App Version  \
# 0  2021-11-10 12:17:06  2021-11-10 12:17:05  2021-11-10 12:18:28    1.25.5218
# 1  2021-11-10 12:17:07  2021-11-10 12:17:05  2021-11-10 12:18:28    1.25.5218
# 2  2021-11-10 12:18:28  2021-11-10 12:17:05  2021-11-10 12:18:28    1.25.5218
# 3  2021-11-10 12:18:33  2021-11-10 12:18:29  2021-11-10 12:20:32    1.25.5218
# 4  2021-11-10 12:18:34  2021-11-10 12:18:29  2021-11-10 12:20:32    1.25.5218
#
#    iPad Version Firmware Version Age_month Age_group
# 0    / iPad13,4           14.7.1      39.0  (35, 43]
# 1    / iPad13,4           14.7.1      39.0  (35, 43]
# 2    / iPad13,4           14.7.1      39.0  (35, 43]
# 3    / iPad13,4           14.7.1      39.0  (35, 43]
# 4    / iPad13,4           14.7.1      39.0  (35, 43]
#
# [5 rows x 25 columns]

# %%
#Table measure counts by PIN (one column for PIN, age group
df.groupby('Age_group').agg({"PIN": "nunique"})
# Out:
#            PIN
# Age_group
# (10, 12]     1
# (12, 15]     5
# (15, 18]     3
# (18, 21]     9
# (21, 24]     2
# (24, 27]     7
# (27, 30]     4
# (3, 4]       5
# (30, 35]     7
# (35, 43]    10
# (4, 5]       4
# (5, 6]       3
# (6, 8]       7
# (8, 10]      5

# %%
t1=df.groupby(['PIN','Assessment Name']).agg({'Inst': "nunique"})

# %%
# one column for each of the ~35 Inst [instrument names])
t2=df.groupby(['PIN','Assessment Name'])['Inst'].apply(list)
task4 = pd.merge(t1,t2, on=['PIN','Assessment Name'])

# %%
task4.columns=['unique_inst_count', 'Inst']

# %%
df.to_csv('C:/Users/tsb7592/Downloads/combined_data.csv', index=False)

# %%
import pandas as pd
df=pd.read_csv('C:/Users/tsb7592/Downloads/combined_data.csv')

# %%
import ast
def count_freq(row):
    dc ={}
    for i in row:
        if i not in dc:
            dc[i] = 0
        else:
            dc[i]+=1
   # convertedDict = ast.literal_eval(dc)

    return dc

# %%
task4['freq'] =task4['Inst'].apply(count_freq)

# %%
task4.tail()
# Out:
#                         unique_inst_count  \
# PIN    Assessment Name
# WI032C Assessment 1                    14
# WI032P Assessment 1                     4
# WI033C Assessment 1                     6
#        Assessment 2                    17
# WI24C  Assessment 1                    17
#
#                                                                      Inst  \
# PIN    Assessment Name
# WI032C Assessment 1     [Mullen Receptive, Mullen Receptive, Mullen Re...
# WI032P Assessment 1     [Infant Behavior Questionnaire - Revised - Ver...
# WI033C Assessment 1     [Early Childhood Behavior Questionnaire - Very...
#        Assessment 2     [Mullen Receptive, Mullen Receptive, Mullen Re...
# WI24C  Assessment 1     [Mullen Receptive, Mullen Receptive, Mullen Re...
#
#                                                                      freq
# PIN    Assessment Name
# WI032C Assessment 1     {'Mullen Receptive': 4, 'Mullen Expressive Pro...
# WI032P Assessment 1     {'Infant Behavior Questionnaire - Revised - Ve...
# WI033C Assessment 1     {'Early Childhood Behavior Questionnaire - Ver...
#        Assessment 2     {'Mullen Receptive': 7, 'Mullen Expressive Pro...
# WI24C  Assessment 1     {'Mullen Receptive': 6, 'Mullen Expressive Pro...

# %%
task4= pd.read_csv('C:/Users/tsb7592/Downloads/task4.csv')

# %%
for index, row in task4.iterrows():
    dictionary = row['freq']
    for key, v in dictionary.items():
        task4.loc[index,key] = v

# %%
task4.head()
# Out:
#                             unique_inst_count  \
# PIN        Assessment Name
# Appletonc1 Assessment 1                    23
# Appletonq  Assessment 1                     5
# M018c      Assessment 3                    23
# MN001c     Assessment 1                     6
# MN001p     Assessment 2                     1
#
#                                                                          Inst  \
# PIN        Assessment Name
# Appletonc1 Assessment 1     [Mullen Receptive, Mullen Receptive, Mullen Re...
# Appletonq  Assessment 1     [Children's Behavior Questionnaire - Very Shor...
# M018c      Assessment 3     [Mullen Receptive, Mullen Receptive, Mullen Re...
# MN001c     Assessment 1     [Mullen Receptive, Mullen Receptive, Mullen Re...
# MN001p     Assessment 2     [Infant Behavior Questionnaire - Revised - Ver...
#
#                                                                          freq  \
# PIN        Assessment Name
# Appletonc1 Assessment 1     {'Mullen Receptive': 2, 'Mullen Expressive Pro...
# Appletonq  Assessment 1     {'Children's Behavior Questionnaire - Very Sho...
# M018c      Assessment 3     {'Mullen Receptive': 4, 'Mullen Expressive Pro...
# MN001c     Assessment 1     {'Mullen Receptive': 6, 'Mullen Expressive Pro...
# MN001p     Assessment 2     {'Infant Behavior Questionnaire - Revised - Ve...
#
#                             Mullen Receptive  Mullen Expressive Prompted  \
# PIN        Assessment Name
# Appletonc1 Assessment 1                  2.0                         3.0
# Appletonq  Assessment 1                  NaN                         NaN
# M018c      Assessment 3                  4.0                         3.0
# MN001c     Assessment 1                  6.0                         5.0
# MN001p     Assessment 2                  NaN                         NaN
#
#                             Verbal Counting  Object Counting  Give_N  \
# PIN        Assessment Name
# Appletonc1 Assessment 1                 2.0              5.0    13.0
# Appletonq  Assessment 1                 NaN              NaN     NaN
# M018c      Assessment 3                 2.0              5.0    13.0
# MN001c     Assessment 1                 NaN              NaN     NaN
# MN001p     Assessment 2                 NaN              NaN     NaN
#
#                             Memory Task Learning  Visual Delayed Response  \
# PIN        Assessment Name
# Appletonc1 Assessment 1                     21.0                     12.0
# Appletonq  Assessment 1                      NaN                      NaN
# M018c      Assessment 3                     21.0                     12.0
# MN001c     Assessment 1                      NaN                      NaN
# MN001p     Assessment 2                      NaN                      NaN
#
#                             ...  \
# PIN        Assessment Name  ...
# Appletonc1 Assessment 1     ...
# Appletonq  Assessment 1     ...
# M018c      Assessment 3     ...
# MN001c     Assessment 1     ...
# MN001p     Assessment 2     ...
#
#                             PROMIS EC Parent-Report SF v1.0 - Social Relationships - Peer Relationships 4a  \
# PIN        Assessment Name
# Appletonc1 Assessment 1                                                   NaN
# Appletonq  Assessment 1                                                   5.0
# M018c      Assessment 3                                                   NaN
# MN001c     Assessment 1                                                   NaN
# MN001p     Assessment 2                                                   NaN
#
#                             CDI: Expressive  Looking While Listening  \
# PIN        Assessment Name
# Appletonc1 Assessment 1                 NaN                      NaN
# Appletonq  Assessment 1                23.0                      NaN
# M018c      Assessment 3                 NaN                      2.0
# MN001c     Assessment 1                 NaN                      NaN
# MN001p     Assessment 2                 NaN                      NaN
#
#                             Infant Behavior Questionnaire - Revised - Very Short Form  \
# PIN        Assessment Name
# Appletonc1 Assessment 1                                                   NaN
# Appletonq  Assessment 1                                                   NaN
# M018c      Assessment 3                                                   NaN
# MN001c     Assessment 1                                                   NaN
# MN001p     Assessment 2                                                  38.0
#
#                             Early Childhood Behavior Questionnaire - Very Short Form  \
# PIN        Assessment Name
# Appletonc1 Assessment 1                                                   NaN
# Appletonq  Assessment 1                                                   NaN
# M018c      Assessment 3                                                   NaN
# MN001c     Assessment 1                                                   NaN
# MN001p     Assessment 2                                                   NaN
#
#                             Executive Function  Numerical Change Detection  \
# PIN        Assessment Name
# Appletonc1 Assessment 1                    NaN                         NaN
# Appletonq  Assessment 1                    NaN                         NaN
# M018c      Assessment 3                    NaN                         NaN
# MN001c     Assessment 1                    NaN                         NaN
# MN001p     Assessment 2                    NaN                         NaN
#
#                             Spatial Change Detection  CDI: Receptive  \
# PIN        Assessment Name
# Appletonc1 Assessment 1                          NaN             NaN
# Appletonq  Assessment 1                          NaN             NaN
# M018c      Assessment 3                          NaN             NaN
# MN001c     Assessment 1                          NaN             NaN
# MN001p     Assessment 2                          NaN             NaN
#
#                             Shape Matching Manipulatives
# PIN        Assessment Name
# Appletonc1 Assessment 1                              NaN
# Appletonq  Assessment 1                              NaN
# M018c      Assessment 3                              NaN
# MN001c     Assessment 1                              NaN
# MN001p     Assessment 2                              NaN
#
# [5 rows x 39 columns]

# %%
task4.drop(columns=['Inst','freq']).to_csv('C:/Users/tsb7592/Downloads/task4.csv')

# %% [markdown]
# # Task 5-6

# %%
df =df[df['Score']!='SKIP']

# %%
df['Score'] =pd.to_numeric(df['Score'])

# %%
df.groupby(['PIN','Assessment Name','Inst'])['Score'].sum().unstack()
# Out:
# Inst                        CDI: Expressive  CDI: Receptive  \
# PIN        Assessment Name
# Appletonc1 Assessment 1                 NaN             NaN
# Appletonq  Assessment 1                11.0             NaN
# M018c      Assessment 3                 NaN             NaN
# MN001c     Assessment 1                 NaN             NaN
# MN001p     Assessment 2                 NaN             NaN
# ...                                     ...             ...
# WI032C     Assessment 1                 NaN             NaN
# WI032P     Assessment 1                 NaN             5.0
# WI033C     Assessment 1                13.0            34.0
#            Assessment 2                 NaN             NaN
# WI24C      Assessment 1                 NaN             NaN
#
# Inst                        Caregiver Checklist  \
# PIN        Assessment Name
# Appletonc1 Assessment 1                     NaN
# Appletonq  Assessment 1                    19.0
# M018c      Assessment 3                     NaN
# MN001c     Assessment 1                     NaN
# MN001p     Assessment 2                     NaN
# ...                                         ...
# WI032C     Assessment 1                     NaN
# WI032P     Assessment 1                    24.0
# WI033C     Assessment 1                     5.0
#            Assessment 2                     NaN
# WI24C      Assessment 1                     NaN
#
# Inst                        Children's Behavior Questionnaire - Very Short Form  \
# PIN        Assessment Name
# Appletonc1 Assessment 1                                                   NaN
# Appletonq  Assessment 1                                                 174.0
# M018c      Assessment 3                                                   NaN
# MN001c     Assessment 1                                                   NaN
# MN001p     Assessment 2                                                   NaN
# ...                                                                       ...
# WI032C     Assessment 1                                                   NaN
# WI032P     Assessment 1                                                   NaN
# WI033C     Assessment 1                                                   NaN
#            Assessment 2                                                   NaN
# WI24C      Assessment 1                                                   NaN
#
# Inst                        Early Childhood Behavior Questionnaire - Very Short Form  \
# PIN        Assessment Name
# Appletonc1 Assessment 1                                                   NaN
# Appletonq  Assessment 1                                                   NaN
# M018c      Assessment 3                                                   NaN
# MN001c     Assessment 1                                                   NaN
# MN001p     Assessment 2                                                   NaN
# ...                                                                       ...
# WI032C     Assessment 1                                                   NaN
# WI032P     Assessment 1                                                   NaN
# WI033C     Assessment 1                                                 155.0
#            Assessment 2                                                   NaN
# WI24C      Assessment 1                                                   NaN
#
# Inst                        Executive Function  Get Up and Go  Give_N  \
# PIN        Assessment Name
# Appletonc1 Assessment 1                    NaN           44.0     0.0
# Appletonq  Assessment 1                    NaN            NaN     NaN
# M018c      Assessment 3                    NaN           30.0     3.0
# MN001c     Assessment 1                    NaN            2.0     NaN
# MN001p     Assessment 2                    NaN            NaN     NaN
# ...                                        ...            ...     ...
# WI032C     Assessment 1                    0.0            5.0     NaN
# WI032P     Assessment 1                    NaN            NaN     NaN
# WI033C     Assessment 1                    NaN            NaN     NaN
#            Assessment 2                    0.0           37.0     NaN
# WI24C      Assessment 1                    0.0           10.0     NaN
#
# Inst                        Global Self-Regulation  \
# PIN        Assessment Name
# Appletonc1 Assessment 1                        3.0
# Appletonq  Assessment 1                        NaN
# M018c      Assessment 3                        2.0
# MN001c     Assessment 1                        NaN
# MN001p     Assessment 2                        NaN
# ...                                            ...
# WI032C     Assessment 1                        3.0
# WI032P     Assessment 1                        NaN
# WI033C     Assessment 1                        NaN
#            Assessment 2                        2.0
# WI24C      Assessment 1                        3.0
#
# Inst                        Infant Behavior Questionnaire - Revised - Very Short Form  \
# PIN        Assessment Name
# Appletonc1 Assessment 1                                                   NaN
# Appletonq  Assessment 1                                                   NaN
# M018c      Assessment 3                                                   NaN
# MN001c     Assessment 1                                                   NaN
# MN001p     Assessment 2                                                 143.0
# ...                                                                       ...
# WI032C     Assessment 1                                                   NaN
# WI032P     Assessment 1                                                 165.0
# WI033C     Assessment 1                                                   NaN
#            Assessment 2                                                   NaN
# WI24C      Assessment 1                                                   NaN
#
# Inst                        ...  Reach To Eat  Shape Matching  \
# PIN        Assessment Name  ...
# Appletonc1 Assessment 1     ...          39.0            20.0
# Appletonq  Assessment 1     ...           NaN             NaN
# M018c      Assessment 3     ...          25.0             9.0
# MN001c     Assessment 1     ...           0.0             NaN
# MN001p     Assessment 2     ...           NaN             NaN
# ...                         ...           ...             ...
# WI032C     Assessment 1     ...           9.0             NaN
# WI032P     Assessment 1     ...           NaN             NaN
# WI033C     Assessment 1     ...           NaN             NaN
#            Assessment 2     ...          39.0             NaN
# WI24C      Assessment 1     ...          30.0             NaN
#
# Inst                        Shape Matching Manipulatives  Sit and Stand  \
# PIN        Assessment Name
# Appletonc1 Assessment 1                              NaN           13.0
# Appletonq  Assessment 1                              NaN            NaN
# M018c      Assessment 3                              NaN            8.0
# MN001c     Assessment 1                              NaN           13.0
# MN001p     Assessment 2                              NaN            NaN
# ...                                                  ...            ...
# WI032C     Assessment 1                              NaN           11.0
# WI032P     Assessment 1                              NaN            NaN
# WI033C     Assessment 1                              NaN            NaN
#            Assessment 2                              0.0            3.0
# WI24C      Assessment 1                              0.0           18.0
#
# Inst                        Social Observation  Spatial Change Detection  \
# PIN        Assessment Name
# Appletonc1 Assessment 1                   23.0                       NaN
# Appletonq  Assessment 1                    NaN                       NaN
# M018c      Assessment 3                   11.0                       NaN
# MN001c     Assessment 1                    NaN                       NaN
# MN001p     Assessment 2                    NaN                       NaN
# ...                                        ...                       ...
# WI032C     Assessment 1                    5.0                       0.0
# WI032P     Assessment 1                    NaN                       NaN
# WI033C     Assessment 1                    NaN                       NaN
#            Assessment 2                    9.0                       0.0
# WI24C      Assessment 1                    3.0                       0.0
#
# Inst                        Toy Out of Reach  Verbal Counting  \
# PIN        Assessment Name
# Appletonc1 Assessment 1                 20.0              0.0
# Appletonq  Assessment 1                  NaN              NaN
# M018c      Assessment 3                 19.0              0.0
# MN001c     Assessment 1                  NaN              NaN
# MN001p     Assessment 2                  NaN              NaN
# ...                                      ...              ...
# WI032C     Assessment 1                 14.0              NaN
# WI032P     Assessment 1                  NaN              NaN
# WI033C     Assessment 1                  NaN              NaN
#            Assessment 2                 18.0              0.0
# WI24C      Assessment 1                 20.0              0.0
#
# Inst                        Visual Delayed Response  Who Has More
# PIN        Assessment Name
# Appletonc1 Assessment 1                         5.0          14.0
# Appletonq  Assessment 1                         NaN           NaN
# M018c      Assessment 3                         4.0           1.0
# MN001c     Assessment 1                         NaN           NaN
# MN001p     Assessment 2                         NaN           NaN
# ...                                             ...           ...
# WI032C     Assessment 1                         NaN           NaN
# WI032P     Assessment 1                         NaN           NaN
# WI033C     Assessment 1                         NaN           NaN
#            Assessment 2                         NaN           NaN
# WI24C      Assessment 1                         NaN           NaN
#
# [109 rows x 36 columns]

# %%
#Overall xocre by instrument by PIN
#5.Sum the scores by instrument by PIN, and summarize overall and by age group (for Inst that produce scores)

summary = df.groupby(['PIN','Assessment Name','Age_group','Inst'])['Score'].sum().unstack()
summary
# Out:
# Inst                                  CDI: Expressive  CDI: Receptive  \
# PIN        Assessment Name Age_group
# Appletonc1 Assessment 1    (35, 43]               NaN             NaN
# M018c      Assessment 3    (27, 30]               NaN             NaN
# MN001c     Assessment 1    (3, 4]                 NaN             NaN
# MN003c     Assessment 1    (3, 4]                 NaN             NaN
# Mn002c     Assessment 1    (27, 30]               NaN             NaN
# ...                                               ...             ...
# WI031C     Assessment 2    (12, 15]               2.0            19.0
# WI032C     Assessment 1    (6, 8]                 NaN             NaN
# WI032P     Assessment 1    (6, 8]                 NaN             5.0
# WI033C     Assessment 2    (18, 21]               NaN             NaN
# WI24C      Assessment 1    (12, 15]               NaN             NaN
#
# Inst                                  Caregiver Checklist  \
# PIN        Assessment Name Age_group
# Appletonc1 Assessment 1    (35, 43]                   NaN
# M018c      Assessment 3    (27, 30]                   NaN
# MN001c     Assessment 1    (3, 4]                     NaN
# MN003c     Assessment 1    (3, 4]                     NaN
# Mn002c     Assessment 1    (27, 30]                   NaN
# ...                                                   ...
# WI031C     Assessment 2    (12, 15]                   2.0
# WI032C     Assessment 1    (6, 8]                     NaN
# WI032P     Assessment 1    (6, 8]                    24.0
# WI033C     Assessment 2    (18, 21]                   NaN
# WI24C      Assessment 1    (12, 15]                   NaN
#
# Inst                                  Children's Behavior Questionnaire - Very Short Form  \
# PIN        Assessment Name Age_group
# Appletonc1 Assessment 1    (35, 43]                                                 NaN
# M018c      Assessment 3    (27, 30]                                                 NaN
# MN001c     Assessment 1    (3, 4]                                                   NaN
# MN003c     Assessment 1    (3, 4]                                                   NaN
# Mn002c     Assessment 1    (27, 30]                                                 NaN
# ...                                                                                 ...
# WI031C     Assessment 2    (12, 15]                                                 NaN
# WI032C     Assessment 1    (6, 8]                                                   NaN
# WI032P     Assessment 1    (6, 8]                                                   NaN
# WI033C     Assessment 2    (18, 21]                                                 NaN
# WI24C      Assessment 1    (12, 15]                                                 NaN
#
# Inst                                  Early Childhood Behavior Questionnaire - Very Short Form  \
# PIN        Assessment Name Age_group
# Appletonc1 Assessment 1    (35, 43]                                                 NaN
# M018c      Assessment 3    (27, 30]                                                 NaN
# MN001c     Assessment 1    (3, 4]                                                   NaN
# MN003c     Assessment 1    (3, 4]                                                   NaN
# Mn002c     Assessment 1    (27, 30]                                                 NaN
# ...                                                                                 ...
# WI031C     Assessment 2    (12, 15]                                               122.0
# WI032C     Assessment 1    (6, 8]                                                   NaN
# WI032P     Assessment 1    (6, 8]                                                   NaN
# WI033C     Assessment 2    (18, 21]                                                 NaN
# WI24C      Assessment 1    (12, 15]                                                 NaN
#
# Inst                                  Executive Function  Get Up and Go  \
# PIN        Assessment Name Age_group
# Appletonc1 Assessment 1    (35, 43]                  NaN           44.0
# M018c      Assessment 3    (27, 30]                  NaN           30.0
# MN001c     Assessment 1    (3, 4]                    NaN            2.0
# MN003c     Assessment 1    (3, 4]                    NaN            2.0
# Mn002c     Assessment 1    (27, 30]                  NaN           45.0
# ...                                                  ...            ...
# WI031C     Assessment 2    (12, 15]                  0.0           11.0
# WI032C     Assessment 1    (6, 8]                    0.0            5.0
# WI032P     Assessment 1    (6, 8]                    NaN            NaN
# WI033C     Assessment 2    (18, 21]                  0.0           37.0
# WI24C      Assessment 1    (12, 15]                  0.0           10.0
#
# Inst                                  Give_N  Global Self-Regulation  \
# PIN        Assessment Name Age_group
# Appletonc1 Assessment 1    (35, 43]      0.0                     3.0
# M018c      Assessment 3    (27, 30]      3.0                     2.0
# MN001c     Assessment 1    (3, 4]        NaN                     NaN
# MN003c     Assessment 1    (3, 4]        NaN                     NaN
# Mn002c     Assessment 1    (27, 30]      1.0                     3.0
# ...                                      ...                     ...
# WI031C     Assessment 2    (12, 15]      NaN                     3.0
# WI032C     Assessment 1    (6, 8]        NaN                     3.0
# WI032P     Assessment 1    (6, 8]        NaN                     NaN
# WI033C     Assessment 2    (18, 21]      NaN                     2.0
# WI24C      Assessment 1    (12, 15]      NaN                     3.0
#
# Inst                                  Infant Behavior Questionnaire - Revised - Very Short Form  \
# PIN        Assessment Name Age_group
# Appletonc1 Assessment 1    (35, 43]                                                 NaN
# M018c      Assessment 3    (27, 30]                                                 NaN
# MN001c     Assessment 1    (3, 4]                                                   NaN
# MN003c     Assessment 1    (3, 4]                                                   NaN
# Mn002c     Assessment 1    (27, 30]                                                 NaN
# ...                                                                                 ...
# WI031C     Assessment 2    (12, 15]                                                 NaN
# WI032C     Assessment 1    (6, 8]                                                   NaN
# WI032P     Assessment 1    (6, 8]                                                 165.0
# WI033C     Assessment 2    (18, 21]                                                 NaN
# WI24C      Assessment 1    (12, 15]                                                 NaN
#
# Inst                                  ...  Reach To Eat  Shape Matching  \
# PIN        Assessment Name Age_group  ...
# Appletonc1 Assessment 1    (35, 43]   ...          39.0            20.0
# M018c      Assessment 3    (27, 30]   ...          25.0             9.0
# MN001c     Assessment 1    (3, 4]     ...           0.0             NaN
# MN003c     Assessment 1    (3, 4]     ...          17.0             NaN
# Mn002c     Assessment 1    (27, 30]   ...          19.0            15.0
# ...                                   ...           ...             ...
# WI031C     Assessment 2    (12, 15]   ...          35.0             NaN
# WI032C     Assessment 1    (6, 8]     ...           9.0             NaN
# WI032P     Assessment 1    (6, 8]     ...           NaN             NaN
# WI033C     Assessment 2    (18, 21]   ...          39.0             NaN
# WI24C      Assessment 1    (12, 15]   ...          30.0             NaN
#
# Inst                                  Shape Matching Manipulatives  \
# PIN        Assessment Name Age_group
# Appletonc1 Assessment 1    (35, 43]                            NaN
# M018c      Assessment 3    (27, 30]                            NaN
# MN001c     Assessment 1    (3, 4]                              NaN
# MN003c     Assessment 1    (3, 4]                              NaN
# Mn002c     Assessment 1    (27, 30]                            NaN
# ...                                                            ...
# WI031C     Assessment 2    (12, 15]                            0.0
# WI032C     Assessment 1    (6, 8]                              NaN
# WI032P     Assessment 1    (6, 8]                              NaN
# WI033C     Assessment 2    (18, 21]                            0.0
# WI24C      Assessment 1    (12, 15]                            0.0
#
# Inst                                  Sit and Stand  Social Observation  \
# PIN        Assessment Name Age_group
# Appletonc1 Assessment 1    (35, 43]            13.0                23.0
# M018c      Assessment 3    (27, 30]             8.0                11.0
# MN001c     Assessment 1    (3, 4]              13.0                 NaN
# MN003c     Assessment 1    (3, 4]              14.0                 NaN
# Mn002c     Assessment 1    (27, 30]            13.0                45.0
# ...                                             ...                 ...
# WI031C     Assessment 2    (12, 15]            17.0                 4.0
# WI032C     Assessment 1    (6, 8]              11.0                 5.0
# WI032P     Assessment 1    (6, 8]               NaN                 NaN
# WI033C     Assessment 2    (18, 21]             3.0                 9.0
# WI24C      Assessment 1    (12, 15]            18.0                 3.0
#
# Inst                                  Spatial Change Detection  \
# PIN        Assessment Name Age_group
# Appletonc1 Assessment 1    (35, 43]                        NaN
# M018c      Assessment 3    (27, 30]                        NaN
# MN001c     Assessment 1    (3, 4]                          NaN
# MN003c     Assessment 1    (3, 4]                          NaN
# Mn002c     Assessment 1    (27, 30]                        NaN
# ...                                                        ...
# WI031C     Assessment 2    (12, 15]                        0.0
# WI032C     Assessment 1    (6, 8]                          0.0
# WI032P     Assessment 1    (6, 8]                          NaN
# WI033C     Assessment 2    (18, 21]                        0.0
# WI24C      Assessment 1    (12, 15]                        0.0
#
# Inst                                  Toy Out of Reach  Verbal Counting  \
# PIN        Assessment Name Age_group
# Appletonc1 Assessment 1    (35, 43]               20.0              0.0
# M018c      Assessment 3    (27, 30]               19.0              0.0
# MN001c     Assessment 1    (3, 4]                  NaN              NaN
# MN003c     Assessment 1    (3, 4]                  NaN              NaN
# Mn002c     Assessment 1    (27, 30]               15.0              0.0
# ...                                                ...              ...
# WI031C     Assessment 2    (12, 15]               17.0              0.0
# WI032C     Assessment 1    (6, 8]                 14.0              NaN
# WI032P     Assessment 1    (6, 8]                  NaN              NaN
# WI033C     Assessment 2    (18, 21]               18.0              0.0
# WI24C      Assessment 1    (12, 15]               20.0              0.0
#
# Inst                                  Visual Delayed Response  Who Has More
# PIN        Assessment Name Age_group
# Appletonc1 Assessment 1    (35, 43]                       5.0          14.0
# M018c      Assessment 3    (27, 30]                       4.0           1.0
# MN001c     Assessment 1    (3, 4]                         NaN           NaN
# MN003c     Assessment 1    (3, 4]                         NaN           NaN
# Mn002c     Assessment 1    (27, 30]                       2.0           9.0
# ...                                                       ...           ...
# WI031C     Assessment 2    (12, 15]                       NaN           NaN
# WI032C     Assessment 1    (6, 8]                         NaN           NaN
# WI032P     Assessment 1    (6, 8]                         NaN           NaN
# WI033C     Assessment 2    (18, 21]                       NaN           NaN
# WI24C      Assessment 1    (12, 15]                       NaN           NaN
#
# [72 rows x 36 columns]

# %% [markdown]
# # 6.       Measure durations

# %%
#Convert to datetime
df['InstStarted']= pd.to_datetime(df['InstStarted'])
df['InstEnded']= pd.to_datetime(df['InstEnded'])
df['DateCreated']= pd.to_datetime(df['DateCreated'])

# %%
#groupby PIN, Inst to calculate the time spent in each inst by each participant
mni =df.groupby(['PIN','Age_group','Inst'])['InstStarted','InstEnded'].first().reset_index()
# Out:
# <ipython-input-22-f6dea217a5f5>:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   mni =df.groupby(['PIN','Age_group','Inst'])['InstStarted','InstEnded'].first().reset_index()

# %%
#a. Calculate end time minus start time by measure by PIN
mni['Time']=mni['InstEnded']-mni['InstStarted']

# %%
mni['Sec']=round(mni['Time'].dt.total_seconds()/60,2)

# %%
mni.head()
# Out:
#           PIN Age_group                       Inst         InstStarted  \
# 0  Appletonc1  (35, 43]              Get Up and Go 2021-11-10 13:10:48
# 1  Appletonc1  (35, 43]                     Give_N 2021-11-10 12:24:24
# 2  Appletonc1  (35, 43]     Global Self-Regulation 2021-11-10 14:08:41
# 3  Appletonc1  (35, 43]  Make Yours Look Like Mine 2021-11-10 13:57:48
# 4  Appletonc1  (35, 43]       Memory Task Learning 2021-11-10 12:27:17
#
#             InstEnded            Time    Sec
# 0 2021-11-10 13:25:19 0 days 00:14:31  14.52
# 1 2021-11-10 12:27:16 0 days 00:02:52   2.87
# 2 2021-11-10 14:08:47 0 days 00:00:06   0.10
# 3 2021-11-10 14:06:56 0 days 00:09:08   9.13
# 4 2021-11-10 12:30:14 0 days 00:02:57   2.95

# %%
#b. Summarize (inc. medians) by measure, overall and by age group
mni.groupby(['Inst','Age_group'])['Sec'].median()
# Out:
# Inst                     Age_group
# CDI: Expressive          (12, 15]     1.930
#                          (18, 21]     2.945
#                          (21, 24]     5.870
#                          (24, 27]     1.800
#                          (30, 35]     1.600
#                                       ...
# Visual Delayed Response  (35, 43]     4.950
# Who Has More             (24, 27]     3.880
#                          (27, 30]     4.100
#                          (30, 35]     2.885
#                          (35, 43]     3.860
# Name: Sec, Length: 274, dtype: float64

# %%
#c. Add up the durations within a PIN and summarize total time per PIN (even though they will have a different number of measures) – overall and by age group
mni.groupby(['PIN','Age_group'])['Time'].sum()
# Out:
# PIN         Age_group
# Appletonc1  (35, 43]    0 days 01:51:07
# M018c       (27, 30]    0 days 02:01:55
# MN001c      (3, 4]      0 days 00:36:47
# MN003c      (3, 4]      0 days 00:31:01
# Mn002c      (27, 30]    0 days 01:47:11
#                               ...
# WI031C      (12, 15]    0 days 01:12:49
# WI032C      (6, 8]      0 days 00:50:38
# WI032P      (6, 8]      0 days 00:23:37
# WI033C      (18, 21]    0 days 01:21:38
# WI24C       (12, 15]    0 days 01:29:53
# Name: Time, Length: 72, dtype: timedelta64[ns]

# %% [markdown]
# # 7.   Measure-specific analyses are coming (likely after 12/10/2021 – when data collection ends)
