# %% [markdown]
# ## PV Norm

# %%
#Data saved in csv/excel
import glob, os
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
reg = pd.read_csv('C:/Users/tsb7592/Downloads/registration_data_distinct.csv',index_col=0)

# %%
reg.shape
# Out:
# (3260, 13)

# %%
pv = pd.read_csv('C:/Users/tsb7592/Downloads/PV_norm.csv', index_col=0)

# %% [markdown]
# # OR Norm & Original Norm

# %%
pv =pv[pv['ItemID'].str.contains('LAVOC')]

# %%
pv.shape
# Out:
# (1093812, 11)

# %%
pv.ItemID.value_counts()
# Out:
# LAVOC473    31752
# LAVOC355    31740
# LAVOC580    31740
# LAVOC220    31740
# LAVOC403    31740
#             ...
# LAVOC098       48
# LAVOC102       48
# LAVOC024       48
# LAVOC009       48
# LAVOC054       48
# Name: ItemID, Length: 373, dtype: int64

# %%
#Importing the FormWords
xls =  pd.read_excel('C:/Users/tsb7592/Downloads/OR Forms for Norming 07.08.2020_WithWords.xlsx', sheet_name = "Formatted_Forms")

# %%
#Select the 3 needed key values
ps =pv[(pv.Key == 'Score')]
ps['Value'] =pd.to_numeric(ps['Value'])

# %%
ps.Key.value_counts()
# Out:
# Score    91151
# Name: Key, dtype: int64

# %%
ps = ps[['PIN','ItemID','Key','Value']].drop_duplicates()

# %%
ps =ps.pivot_table(index = 'PIN', columns='ItemID',values='Value').reset_index()

# %%
ps
# Out:
# ItemID        PIN  LAVOC001  LAVOC006  LAVOC008  LAVOC009  LAVOC011  LAVOC013  \
# 0             009       NaN       NaN       NaN       NaN       NaN       NaN
# 1        12345678       NaN       NaN       NaN       NaN       NaN       NaN
# 2         5NA6010       NaN       NaN       NaN       NaN       NaN       NaN
# 3        AL Train       NaN       NaN       NaN       NaN       NaN       NaN
# 4       ATLCERT11       NaN       NaN       NaN       NaN       NaN       NaN
# ...           ...       ...       ...       ...       ...       ...       ...
# 3404     msl50005       NaN       NaN       NaN       NaN       NaN       NaN
# 3405     sna40104       NaN       NaN       NaN       NaN       NaN       NaN
# 3406      test444       NaN       NaN       NaN       NaN       NaN       NaN
# 3407     wPX22103       NaN       NaN       NaN       NaN       NaN       NaN
# 3408     wpx22106       NaN       NaN       NaN       NaN       NaN       NaN
#
# ...

# %%
PV_wide =pd.merge(ps, reg[['PIN','Age']], on=['PIN'])

# %%
PV_wide['Source'] ='V3_norm'

# %%
pcol =['PIN','Age','Source',
 'LAVOC001',
 'LAVOC006',
 'LAVOC008',
 'LAVOC009',
 'LAVOC011',
 'LAVOC013',
 'LAVOC014',
 'LAVOC015',
 'LAVOC016',
 'LAVOC017',
 'LAVOC018',
 'LAVOC019',
 'LAVOC022',
 'LAVOC023',
 'LAVOC024',
 'LAVOC026',
 'LAVOC027',
 'LAVOC028',
 'LAVOC029',
 'LAVOC032',
 'LAVOC034',
 'LAVOC038',
 'LAVOC039',
 'LAVOC040',
 'LAVOC041',
 'LAVOC042',
 'LAVOC044',
 'LAVOC047',
 'LAVOC048',
 'LAVOC049',
 'LAVOC052',
 'LAVOC053',
 'LAVOC054',
 'LAVOC055',
 'LAVOC057',
 'LAVOC059',
 'LAVOC062',
 'LAVOC063',
 'LAVOC065',
 'LAVOC066',
 'LAVOC068',
 'LAVOC071',
 'LAVOC072',
 'LAVOC073',
PV_wide=PV_wide[pcol]

# %%
PV_wide.shape
# Out:
# (3239, 376)

# %%
or_norm = pd.read_csv('C:/Users/tsb7592/Downloads/NIHTB_OriginalNorming_CognitionItems.csv')

# %%
or1=or_norm[or_norm.assmnt ==1]

# %%
or1 = or1.rename({'login': 'PIN', 'age': 'Age'}, axis=1)

# %%
or1.head()
# Out:
#      PIN proxlogin  assmnt    year  StudyDay    site  stdyarm  \
# 0  10000     54385       1  2011.0       0.0  Site 1  Group A
# 1  10002     74642       1  2011.0       0.0  Site 1  Group A
# 2  10004                 1  2011.0       0.0  Site 1  Group A
# 3  10007     57916       1  2011.0       0.0  Site 1  Group B
# 4  10009     70054       1  2011.0       0.0  Site 1  Group C
#
#                   ethncty  hispanic_rc   Age  ...  OSDRow5  OSDRow6  OSDRow7  \
# 0  Not Hispanic or Latino            0  10.0  ...      NaN      NaN      NaN
# 1      Hispanic or Latino            1   5.0  ...      NaN      NaN      NaN
# 2      Hispanic or Latino            1  70.0  ...      NaN      NaN      NaN
# 3      Hispanic or Latino            1   3.0  ...      NaN      NaN      NaN
# 4      Hispanic or Latino            1   5.0  ...      NaN      NaN      NaN
#
#    OSDRow8  RAVLTT1  RAVLTT1_Child  RAVLTT2  RAVLTT2_Child  RAVLTT3  \
# ...

# %%
or1['Source'] ='V1_norm'

# %%
ll=['PIN','Age','Source']
for col in or1.columns:
    if col.startswith('LAVOC' ):
        ll.append(col)

# %%
or1 =or1[ll]

# %%
or1.shape
# Out:
# (4859, 406)

# %%
final.head()
# Out:
#          PIN   Age   Source  LAVOC001  LAVOC006  LAVOC008  LAVOC009  LAVOC011  \
# 0        009  21.0  V3_norm       NaN       NaN       NaN       NaN       NaN
# 1   12345678  43.0  V3_norm       NaN       NaN       NaN       NaN       NaN
# 2    5NA6010  64.0  V3_norm       NaN       NaN       NaN       NaN       NaN
# 3   AL Train  33.0  V3_norm       NaN       NaN       NaN       NaN       NaN
# 4  ATLCERT11  38.0  V3_norm       NaN       NaN       NaN       NaN       NaN
#
#    LAVOC013  LAVOC014  ...  LAVOC179  LAVOC185  LAVOC288  LAVOC421  LAVOC438  \
# 0       NaN       NaN  ...       NaN       NaN       NaN       NaN       NaN
# 1       NaN       NaN  ...       NaN       NaN       NaN       NaN       NaN
# 2       NaN       NaN  ...       NaN       NaN       NaN       NaN       NaN
# 3       NaN       NaN  ...       NaN       NaN       NaN       NaN       NaN
# 4       NaN       NaN  ...       NaN       NaN       NaN       NaN       NaN
#
# ...

# %%
set(ll) - set(pcol)
# Out:
# {'LAVOC002',
#  'LAVOC003',
#  'LAVOC004',
#  'LAVOC005',
#  'LAVOC010',
#  'LAVOC021',
#  'LAVOC037',
#  'LAVOC046',
#  'LAVOC051',
#  'LAVOC058',
#  'LAVOC061',
#  'LAVOC064',
#  'LAVOC067',
#  'LAVOC077',
#  'LAVOC087',
#  'LAVOC097',
#  'LAVOC114',
#  'LAVOC121',
#  'LAVOC163',
#  'LAVOC179',
#  'LAVOC185',
#  'LAVOC288',
#  'LAVOC421',
#  'LAVOC438',
#  'LAVOC451',
#  'LAVOC514',
#  'LAVOC585',
#  'LAVOC591',
#  'LAVOC592',
#  'LAVOC_Screen'}

# %% [markdown]
# # EF2 Item scores

# %%
EF = pd.read_csv('C:/Users/tsb7592/Downloads/EF2 Item Scores ALL 010320.csv')

# %%
EF.shape
# Out:
# (101270, 33)

# %%
EF= EF[EF['Assessment Name']=='Assessment 1']

# %%
keep = ['FINAL PIN', 'AgeYrs','ItemID','Score']

# %%
##Select FINAL PIN, AgeYrs, and all variables starting with “LAVOC”.
EF =EF[keep]

# %%
#all variables starting with “LAVOC”.
EF = EF.loc[EF['ItemID'].str.startswith('LAVOC')]

# %%
EF = EF.rename({'FINAL PIN': 'PIN', 'AgeYrs': 'Age'}, axis=1)

# %%
EF =EF.pivot_table(index = ['PIN','Age'], columns='ItemID',values='Score').reset_index()

# %%
EF['Source']='EF2'

# %%
final = PV_wide.append(or1)
final = final.append(EF)

final.head()
# Out:
#          PIN   Age   Source  LAVOC001  LAVOC006  LAVOC008  LAVOC009  LAVOC011  \
# 0        009  21.0  V3_norm       NaN       NaN       NaN       NaN       NaN
# 1   12345678  43.0  V3_norm       NaN       NaN       NaN       NaN       NaN
# 2    5NA6010  64.0  V3_norm       NaN       NaN       NaN       NaN       NaN
# 3   AL Train  33.0  V3_norm       NaN       NaN       NaN       NaN       NaN
# 4  ATLCERT11  38.0  V3_norm       NaN       NaN       NaN       NaN       NaN
#
#    LAVOC013  LAVOC014  ...  LAVOC179  LAVOC185  LAVOC288  LAVOC421  LAVOC438  \
# 0       NaN       NaN  ...       NaN       NaN       NaN       NaN       NaN
# 1       NaN       NaN  ...       NaN       NaN       NaN       NaN       NaN
# 2       NaN       NaN  ...       NaN       NaN       NaN       NaN       NaN
# 3       NaN       NaN  ...       NaN       NaN       NaN       NaN       NaN
# 4       NaN       NaN  ...       NaN       NaN       NaN       NaN       NaN
#
# ...

# %%
final.tail()
# Out:
#              PIN   Age Source  LAVOC001  LAVOC006  LAVOC008  LAVOC009  \
# 351  996743947-2   7.0    EF2       NaN       NaN       NaN       NaN
# 352       Joseph  18.0    EF2       NaN       NaN       NaN       NaN
# 353       Josiah  18.0    EF2       NaN       NaN       NaN       NaN
# 354          Ron  69.0    EF2       NaN       NaN       NaN       NaN
# 355      Sydny M  24.0    EF2       NaN       NaN       NaN       NaN
#
#      LAVOC011  LAVOC013  LAVOC014  ...  LAVOC179  LAVOC185  LAVOC288  \
# 351       NaN       NaN       NaN  ...       NaN       NaN       NaN
# 352       NaN       NaN       NaN  ...       NaN       NaN       NaN
# 353       NaN       NaN       NaN  ...       NaN       NaN       NaN
# 354       NaN       NaN       NaN  ...       NaN       NaN       NaN
# 355       NaN       NaN       NaN  ...       NaN       NaN       NaN
#
#      LAVOC421  LAVOC438  LAVOC451  LAVOC514  LAVOC585  LAVOC591  LAVOC592
# ...

# %%
counter =final.groupby('Source')[pcol[3:]].count().unstack().reset_index()
counter.columns=['ItemID', 'Source', 'count']

# %%
counter =counter.pivot_table(index=['ItemID'], columns='Source', values='count').reset_index()

# %%
counter.head()
# Out:
# Source    ItemID  EF2  V1_norm  V3_norm
# 0       LAVOC001    5       30       20
# 1       LAVOC006    5       26       17
# 2       LAVOC008    8       20       24
# 3       LAVOC009    6       55        2
# 4       LAVOC011    4       21       19

# %%
counter.to_csv('C:/Users/tsb7592/Downloads/pv_counter.csv', index=False)

# %%
final.to_csv('C:/Users/tsb7592/Downloads/PV_wide.csv', index=False)
