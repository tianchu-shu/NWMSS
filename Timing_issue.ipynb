# %%
#Data saved in csv/excel
import glob, os
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

data_dir="C:/Users/tsb7592/Box/Avera NIHTB Data"
os.chdir(data_dir)

# %% [markdown]
# # Compute the Total response time in minutes

# %%
# get all files from all RC In-person subdirectories

all_files = glob.glob('C:\\Users\\tsb7592\\Box\\Avera NIHTB Data\\Rapid City\\*\\In Person\\*CB_Data.csv')

doc =[]
for file in all_files:
    data = pd.read_csv(file)
    print(file)
    doc.append(data)

# get all files from all SF
all_files = glob.glob('C:\\Users\\tsb7592\\Box\\Avera NIHTB Data\\Sioux Falls\\*\\In Person\\*CB_Data.csv')
for file in all_files:
    data = pd.read_csv(file)
    print(file)
    doc.append(data)

all_files = glob.glob('C:\\Users\\tsb7592\\Box\\Avera NIHTB Data\\Sioux Falls\\*\\In Person\\*PVT_Data.csv')
sep= []
for file in all_files:
    data = pd.read_csv(file)
    print(file)
    if data.shape[1]!= 11:
        doc.append(data)

    else:
        sep.append(data)
df = pd.concat(doc)
# Out:
# C:\Users\tsb7592\Box\Avera NIHTB Data\Rapid City\EPRC_00032\In Person\210330_EPRC_00032_A_8Y_NT_CB_Data.csv
# C:\Users\tsb7592\Box\Avera NIHTB Data\Rapid City\EPRC_00160\In Person\210423_EPRC_00160_A_8Y_NT_CB_Data.csv
# C:\Users\tsb7592\Box\Avera NIHTB Data\Rapid City\EPRC_00162\In Person\210407_EPRC_00162_A_8Y_NT_CB_Data.csv
# C:\Users\tsb7592\Box\Avera NIHTB Data\Rapid City\EPRC_00173\In Person\210331_EPRC_00173_A_8Y_NT_CB_Data.csv
# C:\Users\tsb7592\Box\Avera NIHTB Data\Rapid City\EPRC_00179\In Person\210427_EPRC_00179_A_8Y_NT_CB_Data.csv
# C:\Users\tsb7592\Box\Avera NIHTB Data\Rapid City\EPRC_00181\In Person\210420_EPRC_00181_A_8Y_NT_CB_Data.csv
# C:\Users\tsb7592\Box\Avera NIHTB Data\Rapid City\EPRC_00183\In Person\210422_EPRC_00183_8Y_NT_CB_Data.csv
# C:\Users\tsb7592\Box\Avera NIHTB Data\Rapid City\EPRC_00191\In Person\210506_EPRC_00191_A_8Y_NT_CB_Data.csv
# C:\Users\tsb7592\Box\Avera NIHTB Data\Rapid City\EPRC_00380\In Person\210419_EPRC_00380_A_8Y_NT_CB_Data.csv
# C:\Users\tsb7592\Box\Avera NIHTB Data\Rapid City\EPRC_00550\In Person\210412_EPRC_00550_A_8Y_NT_CB_Data.csv
# C:\Users\tsb7592\Box\Avera NIHTB Data\Sioux Falls\EPSF_00832_A\In Person\210413_EPSF_00832_A_8Y_NT_CB_Data.csv
# C:\Users\tsb7592\Box\Avera NIHTB Data\Sioux Falls\EPSF_00836_A\In Person\210413_EPSF_00836_A_8Y_NT_CB_Data.csv
# C:\Users\tsb7592\Box\Avera NIHTB Data\Sioux Falls\EPSF_00847_A\In Person\210412_EPSF_00847_A_8Y_CB_Data.csv
# C:\Users\tsb7592\Box\Avera NIHTB Data\Sioux Falls\EPSF_00944_A\In Person\210416_EPSF_00944_A_8Y_NT_CB_Data.csv
# C:\Users\tsb7592\Box\Avera NIHTB Data\Sioux Falls\EPSF_00944_B\In Person\210416_EPSF_00944_B_8Y_NT_CB_Data.csv
# C:\Users\tsb7592\Box\Avera NIHTB Data\Sioux Falls\EPSF_01247_A\In Person\210412_EPSF_01247_A_8Y_NT_CB_Data.csv
# C:\Users\tsb7592\Box\Avera NIHTB Data\Sioux Falls\EPSF_01247_A\In Person\210414_EPSF_01247_A_8Y_NT_CB_Data.csv
# C:\Users\tsb7592\Box\Avera NIHTB Data\Sioux Falls\EPSF_01666_A\In Person\210412_EPSF_01666_A_8Y_NT_CB_Data.csv
# C:\Users\tsb7592\Box\Avera NIHTB Data\Sioux Falls\EPSF_00943_A\In Person\210409_EPSF_00943_A_9.5Y_M_NT_NS_PVT_Data.csv
# C:\Users\tsb7592\Box\Avera NIHTB Data\Sioux Falls\EPSF_00943_A\In Person\210409_EPSF_00943_A_9.5Y_M_NT_PVT_Data.csv

# %%
sdf = pd.concat(sep)

# %%
sdf.shape
# Out:
# (403, 11)

# %%
#Set two decimal points for display
pd.options.display.float_format = "{:.2f}".format

# %%
df.columns
# Out:
# Index(['PIN', 'DeviceID', 'Assessment Name', 'InstOrdr', 'InstSctn', 'ItmOrdr',
#        'Inst', 'Locale', 'ItemID', 'Response', 'Score', 'Theta', 'TScore',
#        'SE', 'DataType', 'Position', 'ResponseTime', 'DateCreated',
#        'InstStarted', 'InstEnded', 'App Version', 'iPad Version',
#        'Firmware Version'],
#       dtype='object')

# %%
df.head()
# Out:
#                       PIN                              DeviceID  \
# 0  210330_EPRC_00032_A_8Y  DB9A19BF-F81C-4244-9C7F-D0BB4A39D394
# 1  210330_EPRC_00032_A_8Y  DB9A19BF-F81C-4244-9C7F-D0BB4A39D394
# 2  210330_EPRC_00032_A_8Y  DB9A19BF-F81C-4244-9C7F-D0BB4A39D394
# 3  210330_EPRC_00032_A_8Y  DB9A19BF-F81C-4244-9C7F-D0BB4A39D394
# 4  210330_EPRC_00032_A_8Y  DB9A19BF-F81C-4244-9C7F-D0BB4A39D394
#
#   Assessment Name  InstOrdr  InstSctn  ItmOrdr  \
# 0    Assessment 1         1         1        1
# 1    Assessment 1         1         1        2
# 2    Assessment 1         1         1        3
# 3    Assessment 1         1         1        4
# 4    Assessment 1         1         1        5
#
#                                                 Inst Locale        ItemID  \
# 0  NIH Toolbox Picture Vocabulary Test Age 3+ Pra...  en-US   VOCAB_INTRO
# 1  NIH Toolbox Picture Vocabulary Test Age 3+ Pra...  en-US  VOCAB_INSTR1
# 2  NIH Toolbox Picture Vocabulary Test Age 3+ Pra...  en-US  VOCAB_PRACT1
# 3  NIH Toolbox Picture Vocabulary Test Age 3+ Pra...  en-US  VOCAB_PRACT2
# 4  NIH Toolbox Picture Vocabulary Test Age 3+ Pra...  en-US  VOCAB_INSTR2
#
#   Response  ...  SE       DataType  Position  ResponseTime  \
# 0      NaN  ... NaN  informational       NaN           NaN
# 1      NaN  ... NaN  informational       NaN           NaN
# 2        4  ... NaN        integer      1.00          6.43
# 3        3  ... NaN        integer      2.00          6.05
# 4      NaN  ... NaN  informational       NaN           NaN
#
#            DateCreated          InstStarted            InstEnded App Version  \
# 0  2021-03-30 09:43:19  2021-03-30 09:43:16  2021-03-30 09:44:46   1.23.4300
# 1  2021-03-30 09:44:10  2021-03-30 09:43:16  2021-03-30 09:44:46   1.23.4300
# 2  2021-03-30 09:44:17  2021-03-30 09:43:16  2021-03-30 09:44:46   1.23.4300
# 3  2021-03-30 09:44:24  2021-03-30 09:43:16  2021-03-30 09:44:46   1.23.4300
# 4  2021-03-30 09:44:46  2021-03-30 09:43:16  2021-03-30 09:44:46   1.23.4300
#
#                              iPad Version Firmware Version
# 0  iPad Pro 1st Gen (10.5-inch) / iPad7,3           14.4.1
# 1  iPad Pro 1st Gen (10.5-inch) / iPad7,3           14.4.1
# 2  iPad Pro 1st Gen (10.5-inch) / iPad7,3           14.4.1
# 3  iPad Pro 1st Gen (10.5-inch) / iPad7,3           14.4.1
# 4  iPad Pro 1st Gen (10.5-inch) / iPad7,3           14.4.1
#
# [5 rows x 23 columns]

# %%
#Reshape the data for EPSF_00944 and EPSF_00943 from long to wide
sdf=sdf.pivot_table(index=['PIN', 'DeviceID', 'AssessmentName', 'ResponseID', 'ItemID',
       'InstrumentTitle', 'TestName', 'InstrumentID'], columns='Key', values='Value', aggfunc='first').reset_index()

# %%
sdf.columns=['PIN', 'DeviceID', 'Assessment Name', 'ResponseID', 'ItemID',
       'Inst', 'TestName', 'InstrumentID', 'App Version', 'DataType',
       'DateCreated', 'Firmware Version', 'InstEnded',
      'InstOrdr', 'InstSctn', 'InstStarted',
       'ItmOrdr', 'Locale', 'Position', 'Response', 'ResponseTime', 'SE',
       'Score', 'Theta', 'iPad Version']

# %%
sdf =sdf.drop(columns=['ResponseID','TestName','InstrumentID'])

# %%
sdf['Site'] = 'Sioux Falls'

# %%
#combine all the data for time calculation
df = df.append(sdf)

# %%
df.shape
# Out:
# (3292, 24)

# %%
df['PIN'] = df['PIN'].str[7:19]

# %%
#Convert to datetime
df['InstStarted']= pd.to_datetime(df['InstStarted'])
df['InstEnded']= pd.to_datetime(df['InstEnded'])
df['DateCreated']= pd.to_datetime(df['DateCreated'])

# %%
def select_inst(df, select):
    sdata = df.set_index('Inst').filter(like=select, axis=0)
    data= sdata[['PIN','ItemID','DateCreated']]
    
    return data

# %%
def calculate_betweentime(data):
    new_ti=[]
    for pin in data.PIN.unique():
        subset=data[data['PIN']==pin]
        subset['BetweenItemTime']=subset['DateCreated'].diff()
        new_ti.append(subset)
        
    new =pd.concat(new_ti)
    new['BetweenItemTime']=round(new['BetweenItemTime'].dt.total_seconds(),2)
    return new

# %%
# get all files from all RC Remote subdirectories

all_files = glob.glob('C:/Users/tsb7592/Box/Avera NIHTB Data/Rapid City/*/Remote/*CB_Data_R.csv')


doc =[]
for file in all_files:
    data = pd.read_csv(file)
    doc.append(data)
    print(file)

# get all files from all SF Remote subdirectories
all_files = glob.glob('C:/Users/tsb7592/Box/Avera NIHTB Data/Sioux Falls/*/Remote/*CB_Data_R.csv')

for file in all_files:
    data = pd.read_csv(file)
    doc.append(data) 
    print(file)

dfr = pd.concat(doc)
# Out:
# C:/Users/tsb7592/Box/Avera NIHTB Data/Rapid City\EPRC_00032\Remote\210406_EPRC_00032_A_8Y_NT_CB_Data_R.csv
# C:/Users/tsb7592/Box/Avera NIHTB Data/Rapid City\EPRC_00160\Remote\210416_EPRC_00160_A_8Y_NT_CB_Data_R.csv
# C:/Users/tsb7592/Box/Avera NIHTB Data/Rapid City\EPRC_00162\Remote\210414_EPRC_00162_A_8Y_NT_CB_Data_R.csv
# C:/Users/tsb7592/Box/Avera NIHTB Data/Rapid City\EPRC_00173\Remote\210408_EPRC_00173_A_8Y_NT_CB_Data_R.csv
# C:/Users/tsb7592/Box/Avera NIHTB Data/Rapid City\EPRC_00179\Remote\210420_EPRC_00179_A_8Y_NT_CB_Data_R.csv
# C:/Users/tsb7592/Box/Avera NIHTB Data/Rapid City\EPRC_00181\Remote\210415_EPRC_00181_A_8Y_NT_CB_Data_R.csv
# C:/Users/tsb7592/Box/Avera NIHTB Data/Rapid City\EPRC_00183\Remote\210415_EPRC_00183_A_8Y_NT_CB_Data_R.csv
# C:/Users/tsb7592/Box/Avera NIHTB Data/Rapid City\EPRC_00191\Remote\210426_EPRC_00191_A_8Y_NT_CB_Data_R.csv
# C:/Users/tsb7592/Box/Avera NIHTB Data/Rapid City\EPRC_00380\Remote\210412_EPRC_00380_A_8Y_NT_CB_Data_R.csv
# C:/Users/tsb7592/Box/Avera NIHTB Data/Rapid City\EPRC_00550\Remote\210419_EPRC_00550_A_8Y_NT_CB_Data_R.csv
# C:/Users/tsb7592/Box/Avera NIHTB Data/Sioux Falls\EPSF_00832_A\Remote\210408_EPSF_00832_A_8Y_NT_CB_Data_R.csv
# C:/Users/tsb7592/Box/Avera NIHTB Data/Sioux Falls\EPSF_00836_A\Remote\210415_EPSF_00836_A_8Y_NT_CB_Data_R.csv
# C:/Users/tsb7592/Box/Avera NIHTB Data/Sioux Falls\EPSF_00847_A\Remote\210409_EPSF_00847_A_8Y_NT_CB_Data_R.csv
# C:/Users/tsb7592/Box/Avera NIHTB Data/Sioux Falls\EPSF_00944_A\Remote\210409_EPSF_00944_A_8Y_NT_CB_Data_R.csv
# C:/Users/tsb7592/Box/Avera NIHTB Data/Sioux Falls\EPSF_00944_B\Remote\210409_EPSF_00944_B_8Y_NT_CB_Data_R.csv
# C:/Users/tsb7592/Box/Avera NIHTB Data/Sioux Falls\EPSF_01666_A\Remote\210408_EPSF_01666_A_8Y_NT_CB_Data_R.csv

# %%
dfr.columns
# Out:
# Index(['PIN', 'DeviceID', 'Assessment Name', 'InstOrdr', 'InstSctn', 'ItmOrdr',
#        'Inst', 'Locale', 'ItemID', 'Response', 'Score', 'Theta', 'TScore',
#        'SE', 'DataType', 'Position', 'ResponseTime', 'DateCreated',
#        'InstStarted', 'InstEnded', 'App Version', 'iPad Version',
#        'Firmware Version'],
#       dtype='object')

# %%
dfr.Inst.unique()
# Out:
# array(['NIH Toolbox Picture Vocabulary Test Age 3+ Practice v2.1',
#        'NIH Toolbox Picture Vocabulary Test Age 3+ v2.1',
#        'NIH Toolbox Oral Reading Recognition Test Age 3+ v2.1',
#        'NIH Toolbox Pattern Comparison Processing Speed Test Age 7+ Practice v2.1',
#        'NIH Toolbox Pattern Comparison Processing Speed Test Age 7+ v2.1',
#        'NIH Toolbox Picture Sequence Memory Test Age 8+ Form A v2.1',
#        'NIH Toolbox Flanker Inhibitory Control and Attention Test Ages 8-11 v2.1',
#        'NIH Toolbox Dimensional Change Card Sort Test Ages 8-11 v2.1',
#        'NIH Toolbox Picture Sequence Memory Test Age 8+ Form B v2.1'],
#       dtype=object)

# %%
dfr['PIN']=dfr['PIN'].replace(' ', '', regex=True)

# %%
dfr['PIN'] = dfr['PIN'].str[7:19]

# %%
dfr['PIN'].unique()
# Out:
# array(['EPRC_00032_A', 'EPRC_00160_A', 'EPRC_00162_A', 'EPRC_00173_A',
#        'EPRC_00179_A', 'EPRC_00181_A', 'EPRC_00183_A', 'EPRC_00191_A',
#        'EPRC_00380_A', 'EPRC_00550_A', 'EPSF_00832_A', 'EPSF_00836_A',
#        'EPSF_00847_A', 'EPSF_00944_A', 'EPSF_00944_B', 'EPSF_01666_A'],
#       dtype=object)

# %%
dfr['InstStarted']= pd.to_datetime(dfr['InstStarted'])
dfr['InstEnded']= pd.to_datetime(dfr['InstEnded'])
dfr['DateCreated']= pd.to_datetime(dfr['DateCreated'])

# %%
def Combine_diff(df, dfr, select):
    new =select_inst(df, select)
    newr =select_inst(dfr, select)
    
    new=calculate_betweentime(new)
    newr =calculate_betweentime(newr)
    newr.columns=['PIN', 'ItemID', 'DateCreated_R', 'BetweenItemTime_R']
    
    rv = pd.merge(new, newr, on=["PIN",'ItemID'])
    rv.loc[:,'BetweenTimeDiff'] = rv.loc[:,'BetweenItemTime_R'] - rv.loc[:,'BetweenItemTime']
    
    return rv

# %%
flanker = Combine_diff(df, dfr, 'Flanker')
flanker
# Out:
#               PIN                       ItemID         DateCreated  \
# 0    EPRC_00032_A          FLANKER_ARROW_PRAC1 2021-03-30 09:47:56
# 1    EPRC_00032_A          FLANKER_ARROW_PRAC2 2021-03-30 09:48:03
# 2    EPRC_00032_A          FLANKER_ARROW_PRAC3 2021-03-30 09:48:11
# 3    EPRC_00032_A          FLANKER_ARROW_PRAC4 2021-03-30 09:48:18
# 4    EPRC_00032_A     FLANKER_ARROW_CONGRUENT1 2021-03-30 09:48:38
# ..            ...                          ...                 ...
# 379  EPSF_01666_A    FLANKER_ARROW_CONGRUENT16 2021-04-12 16:46:43
# 380  EPSF_01666_A  FLANKER_ARROW_INCONGRUENT17 2021-04-12 16:46:47
# 381  EPSF_01666_A    FLANKER_ARROW_CONGRUENT18 2021-04-12 16:46:52
# 382  EPSF_01666_A    FLANKER_ARROW_CONGRUENT19 2021-04-12 16:46:58
# 383  EPSF_01666_A  FLANKER_ARROW_INCONGRUENT20 2021-04-12 16:47:02
#
#      BetweenItemTime       DateCreated_R  BetweenItemTime_R  BetweenTimeDiff
# 0                NaN 2021-04-06 16:16:29                NaN              NaN
# 1               7.00 2021-04-06 16:16:36               7.00             0.00
# 2               8.00 2021-04-06 16:16:43               7.00            -1.00
# 3               7.00 2021-04-06 16:16:50               7.00             0.00
# 4              20.00 2021-04-06 16:17:13              23.00             3.00
# ..               ...                 ...                ...              ...
# 379             6.00 2021-04-08 16:26:52               6.00             0.00
# 380             4.00 2021-04-08 16:26:58               6.00             2.00
# 381             5.00 2021-04-08 16:27:03               5.00             0.00
# 382             6.00 2021-04-08 16:27:09               6.00             0.00
# 383             4.00 2021-04-08 16:27:15               6.00             2.00
#
# [384 rows x 7 columns]

# %%
flanker.to_csv('C:\\Users\\tsb7592\\Box\\Avera NIHTB Data\\Timing\\flanker.csv', index=False)

# %%
dccs = Combine_diff(df, dfr, 'Dimensional Change Card Sort')
dccs.to_csv('C:\\Users\\tsb7592\\Box\\Avera NIHTB Data\\Timing\\dccs.csv', index=False)

# %%
import numpy as np
import scipy.stats as stats

# %%
pc = Combine_diff(df, dfr, 'Pattern Comparison')
pc.to_csv('C:\\Users\\tsb7592\\Box\\Avera NIHTB Data\\Timing\\pc.csv', index=False)

# %%
#T-test

print('***A matched t-test for those who have both in-person and remote -Flanker***')
print('t-statistic = %6.2f pvalue = %6.2f' % stats.ttest_ind(flanker.dropna().BetweenItemTime, flanker.dropna().BetweenItemTime_R, equal_var = False))
print('degree of Freedom ',(flanker.dropna().shape[0]-1))
print('')
print('***A matched t-test for those who have both in-person and remote - DCCS***')
print('t-statistic = %6.2f pvalue = %6.2f' % stats.ttest_ind(dccs.dropna().BetweenItemTime, dccs.dropna().BetweenItemTime_R, equal_var = False))
print('degree of Freedom ',(dccs.dropna().shape[0]-1))
print('')      
print('***A matched t-test for those who have both in-person and remote - PC***')
print('t-statistic = %6.2f pvalue = %6.2f' % stats.ttest_ind(pc.dropna().BetweenItemTime, pc.dropna().BetweenItemTime_R, equal_var = False))
print('degree of Freedom '  ,(pc.dropna().shape[0]-1))
# Out:
# ***A matched t-test for those who have both in-person and remote -Flanker***
# t-statistic =  -2.46 pvalue =   0.01
# degree of Freedom  367
#
# ***A matched t-test for those who have both in-person and remote - DCCS***
# t-statistic =  -1.34 pvalue =   0.18
# degree of Freedom  591
#
# ***A matched t-test for those who have both in-person and remote - PC***
# t-statistic =  -0.73 pvalue =   0.47
# degree of Freedom  623

# %%
flanker.head()
# Out:
#             PIN                    ItemID         DateCreated  \
# 0  EPRC_00032_A       FLANKER_ARROW_PRAC1 2021-03-30 09:47:56
# 1  EPRC_00032_A       FLANKER_ARROW_PRAC2 2021-03-30 09:48:03
# 2  EPRC_00032_A       FLANKER_ARROW_PRAC3 2021-03-30 09:48:11
# 3  EPRC_00032_A       FLANKER_ARROW_PRAC4 2021-03-30 09:48:18
# 4  EPRC_00032_A  FLANKER_ARROW_CONGRUENT1 2021-03-30 09:48:38
#
#    BetweenItemTime       DateCreated_R  BetweenItemTime_R  BetweenTimeDiff
# 0              NaN 2021-04-06 16:16:29                NaN              NaN
# 1             7.00 2021-04-06 16:16:36               7.00             0.00
# 2             8.00 2021-04-06 16:16:43               7.00            -1.00
# 3             7.00 2021-04-06 16:16:50               7.00             0.00
# 4            20.00 2021-04-06 16:17:13              23.00             3.00

# %% [markdown]
# # Regression

# %%
def dummy_variable(variable, df):
    '''
    Using the binned columns, replace them with dummy columns.
    Inputs:
    df: A panda dataframe
    variable: A list of column headings for binned variables
    Outputs:
    df:A panda dataframe
    '''
    dummy_df = pd.get_dummies(df[variable]).rename(columns = lambda x: str(x))
    df = pd.concat([df, dummy_df], axis=1)
    df.drop([variable], inplace = True, axis=1)
    
    return df

# %%
import statsmodels.api as sm

def Regress(df, exp=False):
    reg = dummy_variable('ItemID', df)
    reg= reg.iloc[:,5:].dropna()
    
    y = reg['BetweenTimeDiff']
    X =  reg.iloc[:,1:]
    ols_model = sm.OLS(y, X)
    ols_results = ols_model.fit()
    print(ols_results.summary())
    print('')
    print('')
    print('Exponential Results')
    exp_model = sm.OLS(np.exp(y), X)
    exp_results = exp_model.fit()
    print(exp_results.summary())

# %%
Regress(flanker)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        BetweenTimeDiff   R-squared:                       0.064
# Model:                            OLS   Adj. R-squared:                  0.004
# Method:                 Least Squares   F-statistic:                     1.063
# Date:                Mon, 21 Jun 2021   Prob (F-statistic):              0.386
# Time:                        14:24:39   Log-Likelihood:                -774.33
# No. Observations:                 368   AIC:                             1595.
# Df Residuals:                     345   BIC:                             1685.
# Df Model:                          22
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# FLANKER_ARROW_CONGRUENT1        2.3125      0.512      4.514      0.000       1.305       3.320
# FLANKER_ARROW_CONGRUENT11       0.3125      0.512      0.610      0.542      -0.695       1.320
# FLANKER_ARROW_CONGRUENT12       0.3750      0.512      0.732      0.465      -0.633       1.383
# FLANKER_ARROW_CONGRUENT14       0.6250      0.512      1.220      0.223      -0.383       1.633
# FLANKER_ARROW_CONGRUENT16       0.2500      0.512      0.488      0.626      -0.758       1.258
# FLANKER_ARROW_CONGRUENT18       0.5000      0.512      0.976      0.330      -0.508       1.508
# FLANKER_ARROW_CONGRUENT19       0.3125      0.512      0.610      0.542      -0.695       1.320
# FLANKER_ARROW_CONGRUENT2        0.4375      0.512      0.854      0.394      -0.570       1.445
# FLANKER_ARROW_CONGRUENT4        0.7500      0.512      1.464      0.144      -0.258       1.758
# FLANKER_ARROW_CONGRUENT6        0.6250      0.512      1.220      0.223      -0.383       1.633
# FLANKER_ARROW_CONGRUENT8        0.2500      0.512      0.488      0.626      -0.758       1.258
# FLANKER_ARROW_CONGRUENT9        0.6250      0.512      1.220      0.223      -0.383       1.633
# FLANKER_ARROW_INCONGRUENT10     0.6250      0.512      1.220      0.223      -0.383       1.633
# FLANKER_ARROW_INCONGRUENT13     0.0625      0.512      0.122      0.903      -0.945       1.070
# FLANKER_ARROW_INCONGRUENT15     0.6250      0.512      1.220      0.223      -0.383       1.633
# FLANKER_ARROW_INCONGRUENT17     0.8125      0.512      1.586      0.114      -0.195       1.820
# FLANKER_ARROW_INCONGRUENT20     0.9375      0.512      1.830      0.068      -0.070       1.945
# FLANKER_ARROW_INCONGRUENT3      0.7500      0.512      1.464      0.144      -0.258       1.758
# FLANKER_ARROW_INCONGRUENT5      0.5625      0.512      1.098      0.273      -0.445       1.570
# FLANKER_ARROW_INCONGRUENT7      0.5625      0.512      1.098      0.273      -0.445       1.570
# FLANKER_ARROW_PRAC1                  0          0        nan        nan           0           0
# FLANKER_ARROW_PRAC2             0.8750      0.512      1.708      0.089      -0.133       1.883
# FLANKER_ARROW_PRAC3             2.1250      0.512      4.148      0.000       1.117       3.133
# FLANKER_ARROW_PRAC4             0.8125      0.512      1.586      0.114      -0.195       1.820
# ==============================================================================
# Omnibus:                      133.031   Durbin-Watson:                   1.656
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             5500.931
# Skew:                          -0.735   Prob(JB):                         0.00
# Kurtosis:                      21.884   Cond. No.                          inf
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is      0. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
#
# Exponential Results
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        BetweenTimeDiff   R-squared:                       0.090
# Model:                            OLS   Adj. R-squared:                  0.032
# Method:                 Least Squares   F-statistic:                     1.548
# Date:                Mon, 21 Jun 2021   Prob (F-statistic):             0.0563
# Time:                        14:24:39   Log-Likelihood:                -3860.7
# No. Observations:                 368   AIC:                             7767.
# Df Residuals:                     345   BIC:                             7857.
# Df Model:                          22
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# FLANKER_ARROW_CONGRUENT1     1.311e+04   2248.673      5.829      0.000    8683.688    1.75e+04
# FLANKER_ARROW_CONGRUENT11       1.6727   2248.673      0.001      0.999   -4421.161    4424.506
# FLANKER_ARROW_CONGRUENT12       1.7801   2248.673      0.001      0.999   -4421.053    4424.614
# FLANKER_ARROW_CONGRUENT14       2.2585   2248.673      0.001      0.999   -4420.575    4425.092
# FLANKER_ARROW_CONGRUENT16       1.6582   2248.673      0.001      0.999   -4421.175    4424.492
# FLANKER_ARROW_CONGRUENT18       3.0751   2248.673      0.001      0.999   -4419.758    4425.909
# FLANKER_ARROW_CONGRUENT19       1.8573   2248.673      0.001      0.999   -4420.976    4424.691
# FLANKER_ARROW_CONGRUENT2        2.3836   2248.673      0.001      0.999   -4420.450    4425.217
# FLANKER_ARROW_CONGRUENT4        3.7130   2248.673      0.002      0.999   -4419.121    4426.546
# FLANKER_ARROW_CONGRUENT6        2.6037   2248.673      0.001      0.999   -4420.230    4425.437
# FLANKER_ARROW_CONGRUENT8        1.9535   2248.673      0.001      0.999   -4420.880    4424.787
# FLANKER_ARROW_CONGRUENT9        2.1418   2248.673      0.001      0.999   -4420.692    4424.975
# FLANKER_ARROW_INCONGRUENT10     2.1418   2248.673      0.001      0.999   -4420.692    4424.975
# FLANKER_ARROW_INCONGRUENT13     1.5397   2248.673      0.001      0.999   -4421.294    4424.373
# FLANKER_ARROW_INCONGRUENT15     2.5109   2248.673      0.001      0.999   -4420.323    4425.344
# FLANKER_ARROW_INCONGRUENT17   508.4754   2248.673      0.226      0.821   -3914.358    4931.309
# FLANKER_ARROW_INCONGRUENT20     3.8506   2248.673      0.002      0.999   -4418.983    4426.684
# FLANKER_ARROW_INCONGRUENT3   3743.5669   2248.673      1.665      0.097    -679.267    8166.400
# FLANKER_ARROW_INCONGRUENT5      2.5880   2248.673      0.001      0.999   -4420.246    4425.422
# FLANKER_ARROW_INCONGRUENT7      2.1511   2248.673      0.001      0.999   -4420.682    4424.985
# FLANKER_ARROW_PRAC1                  0          0        nan        nan           0           0
# FLANKER_ARROW_PRAC2            28.2698   2248.673      0.013      0.990   -4394.564    4451.103
# FLANKER_ARROW_PRAC3           700.1102   2248.673      0.311      0.756   -3722.723    5122.944
# FLANKER_ARROW_PRAC4            11.9164   2248.673      0.005      0.996   -4410.917    4434.750
# ==============================================================================
# Omnibus:                      765.383   Durbin-Watson:                   2.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           886698.167
# Skew:                          14.415   Prob(JB):                         0.00
# Kurtosis:                     241.740   Cond. No.                          inf
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is      0. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
Regress(dccs)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        BetweenTimeDiff   R-squared:                       0.095
# Model:                            OLS   Adj. R-squared:                  0.036
# Method:                 Least Squares   F-statistic:                     1.610
# Date:                Mon, 21 Jun 2021   Prob (F-statistic):             0.0151
# Time:                        14:24:49   Log-Likelihood:                -1685.8
# No. Observations:                 592   AIC:                             3446.
# Df Residuals:                     555   BIC:                             3608.
# Df Model:                          36
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# DCCSMIXED_COLOR_SWITCH15    -0.0625      1.077     -0.058      0.954      -2.179       2.054
# DCCSMIXED_COLOR_SWITCH18     0.1250      1.077      0.116      0.908      -1.991       2.241
# DCCSMIXED_COLOR_SWITCH22     0.6875      1.077      0.638      0.524      -1.429       2.804
# DCCSMIXED_COLOR_SWITCH27    -0.0625      1.077     -0.058      0.954      -2.179       2.054
# DCCSMIXED_COLOR_SWITCH30          0      1.077          0      1.000      -2.116       2.116
# DCCSMIXED_COLOR_SWITCH5      0.6250      1.077      0.580      0.562      -1.491       2.741
# DCCSMIXED_COLOR_SWITCH9     -0.3750      1.077     -0.348      0.728      -2.491       1.741
# DCCSMIXED_SHAPE_REPEAT1      2.3750      1.077      2.204      0.028       0.259       4.491
# DCCSMIXED_SHAPE_REPEAT10     0.1875      1.077      0.174      0.862      -1.929       2.304
# DCCSMIXED_SHAPE_REPEAT11     0.3125      1.077      0.290      0.772      -1.804       2.429
# DCCSMIXED_SHAPE_REPEAT12    -0.0625      1.077     -0.058      0.954      -2.179       2.054
# DCCSMIXED_SHAPE_REPEAT13     5.8125      1.077      5.395      0.000       3.696       7.929
# DCCSMIXED_SHAPE_REPEAT14     0.2500      1.077      0.232      0.817      -1.866       2.366
# DCCSMIXED_SHAPE_REPEAT16     0.2500      1.077      0.232      0.817      -1.866       2.366
# DCCSMIXED_SHAPE_REPEAT17     0.3125      1.077      0.290      0.772      -1.804       2.429
# DCCSMIXED_SHAPE_REPEAT19    -0.0625      1.077     -0.058      0.954      -2.179       2.054
# DCCSMIXED_SHAPE_REPEAT2      0.1250      1.077      0.116      0.908      -1.991       2.241
# DCCSMIXED_SHAPE_REPEAT20     0.4375      1.077      0.406      0.685      -1.679       2.554
# DCCSMIXED_SHAPE_REPEAT21     0.5625      1.077      0.522      0.602      -1.554       2.679
# DCCSMIXED_SHAPE_REPEAT23    -0.1250      1.077     -0.116      0.908      -2.241       1.991
# DCCSMIXED_SHAPE_REPEAT24    -0.4375      1.077     -0.406      0.685      -2.554       1.679
# DCCSMIXED_SHAPE_REPEAT25     0.3125      1.077      0.290      0.772      -1.804       2.429
# DCCSMIXED_SHAPE_REPEAT26     0.1875      1.077      0.174      0.862      -1.929       2.304
# DCCSMIXED_SHAPE_REPEAT28     0.5000      1.077      0.464      0.643      -1.616       2.616
# DCCSMIXED_SHAPE_REPEAT29     0.9375      1.077      0.870      0.385      -1.179       3.054
# DCCSMIXED_SHAPE_REPEAT3      0.1250      1.077      0.116      0.908      -1.991       2.241
# DCCSMIXED_SHAPE_REPEAT4      0.0625      1.077      0.058      0.954      -2.054       2.179
# DCCSMIXED_SHAPE_REPEAT6      0.2500      1.077      0.232      0.817      -1.866       2.366
# DCCSMIXED_SHAPE_REPEAT7      0.3750      1.077      0.348      0.728      -1.741       2.491
# DCCSMIXED_SHAPE_REPEAT8      0.2500      1.077      0.232      0.817      -1.866       2.366
# DCCS_COLOR_PRAC1             6.0625      1.077      5.627      0.000       3.946       8.179
# DCCS_COLOR_PRAC2             0.8125      1.077      0.754      0.451      -1.304       2.929
# DCCS_COLOR_PRAC3             0.6875      1.077      0.638      0.524      -1.429       2.804
# DCCS_COLOR_PRAC4             1.0000      1.077      0.928      0.354      -1.116       3.116
# DCCS_SHAPE_PRAC1         -3.722e-24   6.42e-24     -0.580      0.562   -1.63e-23    8.88e-24
# DCCS_SHAPE_PRAC2             0.4375      1.077      0.406      0.685      -1.679       2.554
# DCCS_SHAPE_PRAC3             0.4375      1.077      0.406      0.685      -1.679       2.554
# DCCS_SHAPE_PRAC4             0.6250      1.077      0.580      0.562      -1.491       2.741
# ==============================================================================
# Omnibus:                     1244.939   Durbin-Watson:                   1.940
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          2785626.391
# Skew:                          15.865   Prob(JB):                         0.00
# Kurtosis:                     337.550   Cond. No.                     1.00e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.6e-31. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
#
# Exponential Results
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        BetweenTimeDiff   R-squared:                       0.061
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                     1.000
# Date:                Mon, 21 Jun 2021   Prob (F-statistic):              0.472
# Time:                        14:24:49   Log-Likelihood:                -54579.
# No. Observations:                 592   AIC:                         1.092e+05
# Df Residuals:                     555   BIC:                         1.094e+05
# Df Model:                          36
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# PSPAC141              0.3333      1.396      0.239      0.811      -2.408       3.075
# PSPAC212                   0      0.729          0      1.000      -1.432       1.432
# PSPAC253             -0.2857      0.646     -0.442      0.658      -1.555       0.983
# PSPACPA1              1.4286      0.646      2.211      0.027       0.160       2.698
# PSPACPA2              4.5714      0.646      7.076      0.000       3.302       5.840
# PSPACPA3              1.0714      0.646      1.658      0.098      -0.198       2.340
# PSPACPA4              0.9286      0.646      1.437      0.151      -0.340       2.198
# PSPACPA5              2.0714      0.646      3.206      0.001       0.802       3.340
# PSPACPA6              1.8571      0.646      2.875      0.004       0.588       3.126
# PSPAC_INSTR                0          0        nan        nan           0           0
# PSPAC_INTRO_INSTR     0.0714      0.646      0.111      0.912      -1.198       1.340
# PSPAC_TRANSITION      3.4286      0.646      5.307      0.000       2.160       4.698
# ==============================================================================
# Omnibus:                      235.808   Durbin-Watson:                   2.122
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            56364.136
# Skew:                          -0.295   Prob(JB):                         0.00
# Kurtosis:                      49.556   Cond. No.                     1.00e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.4e-31. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
#
# Exponential Results
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        BetweenTimeDiff   R-squared:                       0.115
# Model:                            OLS   Adj. R-squared:                  0.029
# Method:                 Least Squares   F-statistic:                     1.343
# Date:                Mon, 21 Jun 2021   Prob (F-statistic):             0.0557
# Time:                        14:24:50   Log-Likelihood:                -12607.
# No. Observations:                 624   AIC:                         2.533e+04
# Df Residuals:                     568   BIC:                         2.557e+04
# Df Model:                          55
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# PSPAC002              2.5049   4.03e+07   6.22e-08      1.000   -7.91e+07    7.91e+07
# PSPAC003              9.3618   4.03e+07   2.32e-07      1.000   -7.91e+07    7.91e+07
# PSPAC004              0.9852   4.35e+07   2.26e-08      1.000   -8.55e+07    8.55e+07
# PSPAC005              1.5822   4.03e+07   3.93e-08      1.000   -7.91e+07    7.91e+07
# PSPAC006              2.9621   4.03e+07   7.35e-08      1.000   -7.91e+07    7.91e+07
# PSPAC007              1.1876   4.03e+07   2.95e-08      1.000   -7.91e+07    7.91e+07
# PSPAC008              1.4909    5.7e+07   2.62e-08      1.000   -1.12e+08    1.12e+08
# PSPAC013              2.4891   4.03e+07   6.18e-08      1.000   -7.91e+07    7.91e+07
# PSPAC014              0.7472   4.77e+07   1.57e-08      1.000   -9.36e+07    9.36e+07
# PSPAC016              0.8104   4.77e+07    1.7e-08      1.000   -9.36e+07    9.36e+07
# PSPAC018              1.4616   4.03e+07   3.63e-08      1.000   -7.91e+07    7.91e+07
# PSPAC019              0.9746   4.03e+07   2.42e-08      1.000   -7.91e+07    7.91e+07
# PSPAC021              1.6440   4.03e+07   4.08e-08      1.000   -7.91e+07    7.91e+07
# PSPAC023              0.8352   4.03e+07   2.07e-08      1.000   -7.91e+07    7.91e+07
# PSPAC024              1.0483   4.03e+07    2.6e-08      1.000   -7.91e+07    7.91e+07
# PSPAC028              5.1726   4.03e+07   1.28e-07      1.000   -7.91e+07    7.91e+07
# PSPAC029              0.8164   4.03e+07   2.03e-08      1.000   -7.91e+07    7.91e+07
# PSPAC030              1.1973   4.03e+07   2.97e-08      1.000   -7.91e+07    7.91e+07
# PSPACPA5            585.2195   4.03e+07   1.45e-05      1.000   -7.91e+07    7.91e+07
# PSPACPA6           1578.1275   4.03e+07   3.92e-05      1.000   -7.91e+07    7.91e+07
# PSPAC_INSTR                0          0        nan        nan           0           0
# PSPAC_INTRO_INSTR  4581.0397   4.03e+07      0.000      1.000   -7.91e+07    7.91e+07
# PSPAC_TRANSITION   3.503e+08   4.03e+07      8.696      0.000    2.71e+08    4.29e+08
# ==============================================================================
# Omnibus:                     1398.687   Durbin-Watson:                   2.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          4433824.926
# Skew:                          18.455   Prob(JB):                         0.00
# Kurtosis:                     414.302   Cond. No.                     1.00e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.4e-31. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# # Plots
# Plot two figures. For both the x-axis is the ItemIDs (as it progresses through the measure, so the practice should come first, then the live items – no need to sort this other than the sequence in which the measures appear). It will get crowded so you can remove the text, I just need the order to be right so we know where in the assessment these difference scores are small or large.
# On the y-axis: for Figure 1, TimeDiff, for Figure 2, BetweenTimeDiff

# %%
# Import seaborn
import seaborn as sns
import matplotlib.pyplot as plt

# Apply the default theme
sns.set() #change style

# Create a visualization
g=sns.relplot(data=flanker,  x="ItemID", y="BetweenTimeDiff", hue='PIN',palette='viridis',height=8.27, aspect=11.7/8.27)
g.set_xticklabels(rotation=60)
g.despine(trim=True)
g.fig.suptitle("Flanker by Item")
leg = g._legend
leg.set_bbox_to_anchor([1.2,1.2])   # coordinates of lower left of bounding box

# %%
g=sns.relplot(data=dccs,  x="ItemID", y="BetweenTimeDiff", hue='PIN', palette='flare', height=9, aspect=13/9)
g.set_xticklabels(rotation=60)
g.despine(trim=True)
g.fig.suptitle("DCCS by Item")
leg = g._legend
leg.set_bbox_to_anchor([1.2,1.2])   # coordinates of lower left of bounding box

# %%
g=sns.relplot(data=pc,  x="ItemID", y="BetweenTimeDiff", hue='PIN', palette="crest",height=9, aspect=13/9)
g.set_xticklabels(rotation=60)
g.despine(trim=True)
g.fig.suptitle("PC by Item")
leg = g._legend
leg.set_bbox_to_anchor([1.2,1.2])

# %% [markdown]
# # Old code

# %%
# Adding jitter
import seaborn as sns
import matplotlib.pyplot as plt
sns.set() #change style

#the points are adjusted (only along the categorical axis) so that they don’t overlap. 
g=sns.catplot(data=flanker,  x="ItemID", y="BetweenTimeDiff", hue='PIN',palette="crest", dodge=True, kind="swarm",
                height=8.27, aspect=11.7/8.27)
g.set_xticklabels(rotation=60)
g.fig.suptitle("Flanker by Item")
leg = g._legend
leg.set_bbox_to_anchor([1,1])   # coordinates of lower left of bounding box

# %%
g=sns.catplot(data=dccs,  x="ItemID", y="BetweenTimeDiff", hue='PIN',palette="crest", dodge=True, kind="swarm",
                height=8.27, aspect=11.7/8.27)
g.set_xticklabels(rotation=60)
g.fig.suptitle("DCCS by Item")
leg = g._legend
leg.set_bbox_to_anchor([0.9,0.8])   # coordinates of lower left of bounding box

# %%
g=sns.catplot(data=pc,  x="ItemID", y="BetweenTimeDiff", hue='PIN',palette="crest", dodge=True, kind="swarm",
                height=8.27, aspect=11.7/8.27)

g.set_xticklabels(rotation=60)
g.fig.suptitle("Pattern Comparison by Item")
leg = g._legend
leg.set_bbox_to_anchor([1,0.8])   # coordinates of lower left of bounding box
