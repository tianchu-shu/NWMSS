# %% [markdown]
# https://www.lighttag.io/blog/krippendorffs-alpha/

# %%
import simpledorff
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

df1 = pd.read_excel('C:/Users/tsb7592/Downloads/NBT Trainee Code Comparison_cleaned.xlsx', sheet_name='Toy Out of Reach1') 
df2 = pd.read_excel('C:/Users/tsb7592/Downloads/NBT Trainee Code Comparison_cleaned.xlsx', sheet_name='Toy Out of Reach2')
df3 = pd.read_excel('C:/Users/tsb7592/Downloads/NBT Trainee Code Comparison_cleaned.xlsx', sheet_name='Toy Out of Reach3')
#Load Your Dataframe
df3.head()
# Out:
#   Participant ID (video file name) Baseline Behavior Intensity Escalation  \
# 0                        P1_29mths        alert/calm  Moderate        Low
# 1                        P3_27mths      alert/active       Low        Low
# 2                       P10_27mths        alert/calm  Moderate        Low
# 3                       P12_18mths        alert/calm  Moderate        Low
# 4                       P18_23mths        alert/calm  Moderate        Low
#
#      Coping    Rater                                              Notes  \
# 0       Low  Natasha                                                NaN
# 1  Moderate  Natasha                                                NaN
# 2  Moderate  Natasha                                                NaN
# 3       Low  Natasha  I considered the reaching across the table as ...
# 4       Low  Natasha                                                NaN
#
#    Unnamed: 7
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %%
df2.head()
# Out:
#   Participant ID (video file name) Baseline Behavior Intensity Escalation  \
# 0                        P1_29mths        alert/calm       Low       None
# 1                        P3_27mths      alert/active       Low        Low
# 2                       P10_27mths        alert/calm  Moderate        Low
# 3                       P12_18mths        alert/calm  Moderate        Low
# 4                       P18_23mths        alert/calm  Moderate        Low
#
#      Coping    Rater  Unnamed: 6  Unnamed: 7  Unnamed: 8 Intensity.1  \
# 0      High  Natasha         NaN         NaN         NaN    Moderate
# 1  Moderate  Natasha         NaN         NaN         NaN         Low
# 2  Moderate  Natasha         NaN         NaN         NaN    Moderate
# 3       Low  Natasha         NaN         NaN         NaN    Moderate
# 4       Low  Natasha         NaN         NaN         NaN    Moderate
#
#   Escalation.1  Coping.1                                              Notes  \
# 0          Low       Low                                                NaN
# 1          Low  Moderate                                                NaN
# 2          Low  Moderate                                                NaN
# 3          Low       Low  I considered the reaching across the table as ...
# 4          Low       Low                                                NaN
#
#    Unnamed: 13
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
bb = pd.read_excel('C:/Users/tsb7592/Downloads/NBT Trainee Code Comparison_cleaned.xlsx', sheet_name='Bubbles') #Load Your Dataframe
bb.head()
# Out:
# C:\Users\tsb7592\Anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py:312: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
#   Participant ID (video file name) Baseline Behavior Intensity Predominance   \
# 0                        P3_27mths        alert/calm       Low           Low
# 1                        P4_19mths      alert/active  Moderate      Moderate
# 2                       P10_27mths      alert/active  Moderate      Moderate
# 3                       P13_28mths      alert/active  Moderate      Moderate
# 4                       P18_23mths      alert/active      High          High
#
#      Rater                                            Notes  Unnamed: 6  \
# 0  Natasha   Stop at 0:49 before giving bubble toy to child         NaN
# 1  Natasha                                              NaN         NaN
# 2  Natasha                                              NaN         NaN
# 3  Natasha  Stop at 0:43 before givving bubble toy to child         NaN
# 4  Natasha                                              NaN         NaN
#
#    Unnamed: 7  Unnamed: 8  Unnamed: 9
# 0         NaN         NaN         NaN
# 1         NaN         NaN         NaN
# 2         NaN         NaN         NaN
# 3         NaN         NaN         NaN
# 4         NaN         NaN         NaN

# %%
import sys 

stdoutOrigin=sys.stdout 
sys.stdout = open("krippendorff's_alpha_output.txt", "w")

# %%
def ka(df, name='TOR'):
    a =simpledorff.calculate_krippendorffs_alpha_for_df(df, experiment_col='Participant ID (video file name)',
                                                 annotator_col='Rater',class_col='Baseline Behavior')
    b = simpledorff.calculate_krippendorffs_alpha_for_df(df, experiment_col='Participant ID (video file name)',
                                                 annotator_col='Rater',   class_col='Intensity')
    print("Baseline Behavior: ", round(a,2))
    print("Intensity: ", round(b,2))
    
    if name == 'TOR':
        c=simpledorff.calculate_krippendorffs_alpha_for_df(df, experiment_col='Participant ID (video file name)',
                                                 annotator_col='Rater',  class_col='Escalation')
        d = simpledorff.calculate_krippendorffs_alpha_for_df(df, experiment_col='Participant ID (video file name)',
                                                 annotator_col='Rater',   class_col='Coping')
        print("Escalation: ", round(c,2))
        print("Coping: ", round(d,2))
    else:
        c=simpledorff.calculate_krippendorffs_alpha_for_df(df, experiment_col='Participant ID (video file name)',
                                                 annotator_col='Rater',  class_col='Predominance ')
        print("Predominance: ", round(c,2))
    print('')    
    return

# %%
ka(df1)

# %%
ka(df2)

# %%
ka(df3)

# %%
ka(bb,'bubble')

# %%
sys.stdout.close()
sys.stdout=stdoutOrigin
